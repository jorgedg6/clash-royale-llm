# %%
import os
import asyncio
import aiohttp
import json
import re
from random import shuffle
import random
import pandas as pd
from dataclasses import dataclass

# %%
from card_utils import read_all_game_data, Card, PlayerCards, PlayerStats

# %%
random.seed(42)

# %%
from deck_rate_fetcher import fetch_deck_rating

# %%
import dotenv
dotenv.load_dotenv()

import nest_asyncio
nest_asyncio.apply()

# %%
from langchain_openai import AzureChatOpenAI
from openai import AsyncAzureOpenAI
from langchain_core.messages import SystemMessage, HumanMessage

# %%
game_cards_list, player_cards_list, player_stats, player_tags_list = read_all_game_data()

# %%
top_decks_per_card = pd.read_json("data/top_decks_per_card.json").to_dict()

# %%
print(top_decks_per_card)
# Out:
# {'Knight': {0: 'Graveyard,Knight,Ice Wizard,Witch,Goblin Hut,Vines,Poison,Barbarian Barrel', 1: 'Balloon,Miner,Little Prince,Knight,Bats,Goblin Cage,Rage,Arrows', 2: 'Mortar,Bandit,Knight,Archers,Ice Spirit,Inferno Tower,Rocket,Arrows', 3: 'Three Musketeers,Battle Ram,Royal Ghost,Bandit,Knight,Hunter,Elixir Collector,Barbarian Barrel', 4: 'Graveyard,Knight,Ice Golem,Bowler,Electro Wizard,Inferno Tower,Poison,The Log'}, 'Archers': {0: 'X Bow,Ice Golem,Archers,Skeletons,Fire Spirit,Tesla,Fireball,The Log', 1: 'Graveyard,Knight,Mega Minion,Archers,Skeletons,Tombstone,Poison,The Log', 2: 'Golem,Bandit,Night Witch,Baby Dragon,Archers,Skeletons,Lightning,The Log', 3: 'Mortar,Knight,Archers,Goblins,Ice Spirit,Rocket,Tornado,The Log', 4: 'Mortar,Knight,Princess,Archers,Skeletons,Ice Spirit,Poison,The Log'}, 'Goblins': {0: 'Giant,Electro Wizard,Night Witch,Mega Minion,Goblins,Tombstone,Poison,Zap', 1: 'Giant,Hog Rider,Musketeer,Minions,Goblins,Skeletons,Fireball,Zap', 2: 'Three Musketeers,Battle Ram,Bandit,Minion Horde,Goblins,Ice Spirit,Heal Spirit,Elixir Collector', 3: 'Ram Rider,Monk,Lumberjack,Magic Archer,Inferno Dragon,Goblins,Fireball,Barbarian Barrel', 4: 'Goblin Giant,Goblin Barrel,Dart Goblin,Goblin Gang,Goblins,Goblin Cage,Arrows,The Log'}, 'Giant': {0: 'Giant,Miner,Bandit,Night Witch,Minion Horde,Minions,Fireball,Zap', 1: 'Giant,Hog Rider,Musketeer,Barbarians,Minions,Elixir Collector,Fireball,Zap', 2: 'Giant,Miner,Musketeer,Minion Horde,Minions,Fireball,The Log,Zap', 3: 'Giant,Prince,Dark Prince,Magic Archer,Mega Minion,Ice Spirit,Poison,Zap', 4: 'Giant,Electro Wizard,Mega Minion,Minions,Skeletons,Elixir Collector,Fireball,Zap'}, 'P.E.K.K.A': {0: 'Miner,Pekka,Bandit,Hunter,Bats,Ice Spirit,Poison,Zap', 1: 'Battle Ram,Pekka,Magic Archer,Minions,Dart Goblin,Ice Spirit,Poison,Zap', 2: 'Battle Ram,Pekka,Bandit,Electro Wizard,Zappies,Flying Machine,Fireball,Zap', 3: 'Mega Knight,Pekka,Valkyrie,Wizard,Baby Dragon,Firecracker,Tornado,The Log', 4: 'Hog Rider,Pekka,Electro Wizard,Minions,Skeletons,Poison,The Log,Zap'}, 'Minions': {0: 'Golem,Night Witch,Baby Dragon,Minions,Skeletons,Tombstone,Lightning,The Log', 1: 'Battle Ram,Royal Recruits,Lumberjack,Inferno Dragon,Minions,Ice Spirit,Fireball,Zap', 2: 'Hog Rider,Pekka,Electro Wizard,Minions,Skeletons,Poison,The Log,Zap', 3: 'Giant,Balloon,Minion Horde,Minions,Skeleton Army,Skeletons,Freeze,Arrows', 4: 'Hog Rider,Royal Ghost,Ice Golem,Inferno Dragon,Minions,Guards,Poison,Zap'}, 'Balloon': {0: 'Balloon,Miner,Ice Golem,Musketeer,Skeletons,Bomb Tower,Vines,Barbarian Barrel', 1: 'Balloon,Miner,Rascals,Ice Golem,Bats,Inferno Tower,Barbarian Barrel,Giant Snowball', 2: 'Balloon,Lumberjack,Bowler,Inferno Dragon,Electro Dragon,Freeze,Tornado,Barbarian Barrel', 3: 'Lava Hound,Balloon,Mini Pekka,Mega Minion,Minions,Fireball,Royal Delivery,Zap', 4: 'Balloon,Ice Golem,Musketeer,Minions,Skeleton Army,Tombstone,Fireball,Zap'}, 'Witch': {0: 'Golem,Bandit,Witch,Night Witch,Inferno Dragon,Fire Spirit,Poison,Tornado', 1: 'Graveyard,Valkyrie,Witch,Zappies,Goblin Hut,Freeze,Mirror,Barbarian Barrel', 2: 'Skeleton Barrel,Giant Skeleton,Witch,Bats,Firecracker,Electro Spirit,Bomb Tower,Tornado', 3: 'Elite Barbarians,Witch,Night Witch,Skeleton Army,Goblins,Rage,Poison,Zap', 4: 'Goblin Drill,Wall Breakers,Skeleton Barrel,Valkyrie,Witch,Mega Minion,Skeletons,Barbarian Barrel'}, 'Barbarians': {0: 'Hog Rider,Goblin Barrel,Barbarians,Minion Horde,Goblins,Spear Goblins,Arrows,Zap', 1: 'Hog Rider,Mini Pekka,Musketeer,Barbarians,Inferno Dragon,Arrows,Giant Snowball,Zap', 2: 'Lava Hound,Miner,Spirit Empress,Barbarians,Flying Machine,Tombstone,Goblin Curse,Zap', 3: 'Golem,Lumberjack,Barbarians,Electro Dragon,Skeleton Dragons,Elixir Collector,Tornado,Barbarian Barrel', 4: 'Goblin Giant,Goblin Demolisher,Barbarians,Dart Goblin,Goblin Gang,Goblin Cage,Arrows,The Log'}, 'Golem': {0: 'Golem,Elite Barbarians,Lumberjack,Night Witch,Mega Minion,Bomber,Arrows,Zap', 1: 'Golem,Lumberjack,Night Witch,Guards,Ice Spirit,Elixir Colle ...

# %%
for card_name in top_decks_per_card:
    for key in top_decks_per_card[card_name].keys():
        deck_list = top_decks_per_card[card_name][key].split(',')
        shuffle(deck_list)
        top_decks_per_card[card_name][key] = deck_list

# %%
print(top_decks_per_card)
# Out:
# {'Knight': {0: ['Witch', 'Goblin Hut', 'Poison', 'Barbarian Barrel', 'Ice Wizard', 'Vines', 'Graveyard', 'Knight'], 1: ['Knight', 'Arrows', 'Little Prince', 'Balloon', 'Bats', 'Rage', 'Goblin Cage', 'Miner'], 2: ['Archers', 'Inferno Tower', 'Knight', 'Ice Spirit', 'Bandit', 'Rocket', 'Arrows', 'Mortar'], 3: ['Royal Ghost', 'Battle Ram', 'Three Musketeers', 'Barbarian Barrel', 'Knight', 'Elixir Collector', 'Hunter', 'Bandit'], 4: ['Inferno Tower', 'Ice Golem', 'The Log', 'Bowler', 'Knight', 'Graveyard', 'Poison', 'Electro Wizard']}, 'Archers': {0: ['Tesla', 'Skeletons', 'Fireball', 'Fire Spirit', 'X Bow', 'The Log', 'Ice Golem', 'Archers'], 1: ['Archers', 'Knight', 'Graveyard', 'The Log', 'Skeletons', 'Mega Minion', 'Poison', 'Tombstone'], 2: ['Skeletons', 'The Log', 'Lightning', 'Night Witch', 'Archers', 'Golem', 'Baby Dragon', 'Bandit'], 3: ['Archers', 'Ice Spirit', 'The Log', 'Knight', 'Tornado', 'Mortar', 'Rocket', 'Goblins'], 4: ['Ice Spirit', 'Skeletons', 'Knight', 'Princess', 'The Log', 'Mortar', 'Poison', 'Archers']}, 'Goblins': {0: ['Goblins', 'Giant', 'Mega Minion', 'Tombstone', 'Electro Wizard', 'Poison', 'Zap', 'Night Witch'], 1: ['Giant', 'Zap', 'Minions', 'Fireball', 'Hog Rider', 'Skeletons', 'Goblins', 'Musketeer'], 2: ['Three Musketeers', 'Minion Horde', 'Bandit', 'Battle Ram', 'Elixir Collector', 'Heal Spirit', 'Ice Spirit', 'Goblins'], 3: ['Inferno Dragon', 'Goblins', 'Fireball', 'Magic Archer', 'Lumberjack', 'Barbarian Barrel', 'Monk', 'Ram Rider'], 4: ['Goblin Giant', 'The Log', 'Arrows', 'Goblin Barrel', 'Dart Goblin', 'Goblin Cage', 'Goblins', 'Goblin Gang']}, 'Giant': {0: ['Minion Horde', 'Zap', 'Giant', 'Bandit', 'Miner', 'Night Witch', 'Minions', 'Fireball'], 1: ['Musketeer', 'Giant', 'Hog Rider', 'Fireball', 'Barbarians', 'Zap', 'Elixir Collector', 'Minions'], 2: ['Miner', 'Zap', 'Fireball', 'The Log', 'Giant', 'Minion Horde', 'Minions', 'Musketeer'], 3: ['Mega Minion', 'Zap', 'Prince', 'Giant', 'Magic Archer', 'Ice Spirit', 'Poison', 'Dark Prince'], 4: ['Electro Wizard', 'Minions', 'Elixir Collector', 'Giant', 'Fireball', 'Mega Minion', 'Skeletons', 'Zap']}, 'P.E.K.K.A': {0: ['Hunter', 'Zap', 'Pekka', 'Miner', 'Bandit', 'Ice Spirit', 'Poison', 'Bats'], 1: ['Poison', 'Ice Spirit', 'Dart Goblin', 'Pekka', 'Zap', 'Battle Ram', 'Minions', 'Magic Archer'], 2: ['Bandit', 'Electro Wizard', 'Battle Ram', 'Pekka', 'Zap', 'Flying Machine', 'Fireball', 'Zappies'], 3: ['Wizard', 'Firecracker', 'Pekka', 'The Log', 'Mega Knight', 'Tornado', 'Baby Dragon', 'Valkyrie'], 4: ['Skeletons', 'Poison', 'Minions', 'Hog Rider', 'Zap', 'The Log', 'Electro Wizard', 'Pekka']}, 'Minions': {0: ['Baby Dragon', 'Lightning', 'Skeletons', 'The Log', 'Golem', 'Minions', 'Tombstone', 'Night Witch'], 1: ['Royal Recruits', 'Fireball', 'Battle Ram', 'Inferno Dragon', 'Ice Spirit', 'Minions', 'Zap', 'Lumberjack'], 2: ['Hog Rider', 'Pekka', 'Zap', 'The Log', 'Electro Wizard', 'Poison', 'Minions', 'Skeletons'], 3: ['Skeletons', 'Minions', 'Skeleton Army', 'Minion Horde', 'Giant', 'Freeze', 'Arrows', 'Balloon'], 4: ['Zap', 'Ice Golem', 'Minions', 'Royal Ghost', 'Guards', 'Poison', 'Hog Rider', 'Inferno Dragon']}, 'Balloon': {0: ['Vines', 'Barbarian Barrel', 'Musketeer', 'Ice Golem', 'Miner', 'Skeletons', 'Balloon', 'Bomb Tower'], 1: ['Rascals', 'Inferno Tower', 'Balloon', 'Giant Snowball', 'Barbarian Barrel', 'Miner', 'Bats', 'Ice Golem'], 2: ['Electro Dragon', 'Bowler', 'Barbarian Barrel', 'Inferno Dragon', 'Freeze', 'Balloon', 'Lumberjack', 'Tornado'], 3: ['Mini Pekka', 'Balloon', 'Zap', 'Minions', 'Lava Hound', 'Fireball', 'Mega Minion', 'Royal Delivery'], 4: ['Musketeer', 'Minions', 'Zap', 'Skeleton Army', 'Ice Golem', 'Balloon', 'Fireball', 'Tombstone']}, 'Witch': {0: ['Fire Spirit', 'Inferno Dragon', 'Golem', 'Poison', 'Tornado', 'Bandit', 'Night Witch', 'Witch'], 1: ['Valkyrie', 'Zappies', 'Witch', 'Freeze', 'Graveyard', 'Goblin Hut', 'Mirror', 'Barbarian Barrel'], 2: ['Skeleton Barrel', 'Witch', 'Firecracker', 'Bats', 'Electro Spirit' ...

# %%
@dataclass
class LLMModel:
    name: str
    instance: AzureChatOpenAI | AsyncAzureOpenAI

# %%
llm_gpt3 = LLMModel(
    name="gpt-35-turbo",
    instance=AzureChatOpenAI(
        model_name="gpt-35-turbo",
        temperature=0,
        max_tokens=None,
        timeout=None,
        max_retries=2,
    )
)

llm_gpt4o = LLMModel(
    name="gpt-4o",
    instance=AzureChatOpenAI(
        model_name="gpt-4o",
        temperature=0,
        max_tokens=None,
        timeout=None,
        max_retries=2,
    )
)

llm_gpt5 = LLMModel(
    name="gpt-5-chat",
    instance=AzureChatOpenAI(
        model_name="gpt-5-chat",
        temperature=0,
        max_tokens=None,
        timeout=None,
        max_retries=2,
    )
)

# %%
class SimpleAIMessage:
    """Clase simple para empaquetar la respuesta con un atributo .content"""
    def __init__(self, content):
        self.content = content

# Adaptador para AsyncAzureOpenAI de openai
class OpenAIClientAdapter:
    def __init__(self, client: AsyncAzureOpenAI, model_name: str, temperature: float = 0):
        self.client = client
        self.model_name = model_name
        self.temperature = temperature
        print(f"Adaptador creado para el modelo: {self.model_name}")

    def _convert_lc_messages_to_dict(self, messages):
        output_messages = []
        for msg in messages:
            role = msg.type
            if role == "human":
                role = "user"
            
            output_messages.append({"role": role, "content": msg.content})
        return output_messages

    async def ainvoke(self, messages):
        try:
            dict_messages = self._convert_lc_messages_to_dict(messages)
            
            response = await self.client.chat.completions.create(
                model=self.model_name,
                messages=dict_messages,
                temperature=self.temperature
            )
            
            content = response.choices[0].message.content
            
            return SimpleAIMessage(content=content)
        
        except Exception as e:
            print(f"Error en el adaptador de OpenAI ({self.model_name}): {e}")
            return SimpleAIMessage(content=None)

# %%
print("Creando clientes y adaptadores...")

async_openai_client = AsyncAzureOpenAI(
    azure_endpoint=dotenv.get_key(dotenv.find_dotenv(), "AZURE_OPENAI_ENDPOINT"),
    api_key=dotenv.get_key(dotenv.find_dotenv(), "AZURE_OPENAI_API_KEY"),
    api_version="2024-05-01-preview"
)

llm_grok_adapter = LLMModel(
    name="grok-4-fast-non-reasoning",
    instance=OpenAIClientAdapter(
        client=async_openai_client,
        model_name="grok-4-fast-non-reasoning",
        temperature=0
    )
)

llm_deepseek_adapter = LLMModel(
    name="DeepSeek-V3.1",
    instance=OpenAIClientAdapter(
        client=async_openai_client,
        model_name="DeepSeek-V3.1",
        temperature=0
    )
)

llm_llama_adapter = LLMModel(
    name="Llama-3.3-70B-Instruct",
    instance=OpenAIClientAdapter(
        client=async_openai_client,
        model_name="Llama-3.3-70B-Instruct",
        temperature=0
    )
)
# Out:
# Creando clientes y adaptadores...
# Adaptador creado para el modelo: grok-4-fast-non-reasoning
# Adaptador creado para el modelo: DeepSeek-V3.1
# Adaptador creado para el modelo: Llama-3.3-70B-Instruct

# %% [markdown]
# ### Test

# %%
import logging
import time
import sys

LOG_LEVEL = logging.INFO 

logging.basicConfig(
    level=LOG_LEVEL,
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler("logs/app_run{}.log".format(time.strftime('%Y%m%d_%H%M%S'))), 
        logging.StreamHandler(sys.stdout) 
    ],
    force=True 
)

logging.info("Logger configurado exitosamente.")
# Out:
# 2025-11-02 18:27:24,563 - root - INFO - Logger configurado exitosamente.

# %%
with open("prompts/human_prompt_no_context.txt", "r", encoding="utf-8") as f:
    human_prompt_no_context = f.read().replace("{", "{{").replace("}", "}}")
    human_prompt_no_context = human_prompt_no_context.replace("\n", " ").replace('"', '\\"')
    human_prompt_no_context = human_prompt_no_context.replace("$", "{").replace("%", "}")

with open("prompts/human_prompt_context.txt", "r", encoding="utf-8") as f:
    human_prompt_context = f.read().replace("{", "{{").replace("}", "}}")
    human_prompt_context = human_prompt_context.replace("\n", " ").replace('"', '\\"')
    human_prompt_context = human_prompt_context.replace("$", "{").replace("%", "}")

with open("prompts/system_prompt.txt", "r", encoding="utf-8") as f:
    system_prompt = f.read()

# %%
score_mapping = {
    "RIP": 0,
    "Bad": 1,
    "Mediocre": 2,
    "Good": 3,
    "Great!": 4,
    "Godly!": 5,
}

# %%
def process_deck_rating(rating: str) -> dict:
    rating = rating.strip()
    rating = rating.split(" ")
    ratings = {
        "Attack": score_mapping.get(rating[1], -1),
        "Defense": score_mapping.get(rating[3], -1),
        "Synergy": score_mapping.get(rating[5], -1),
        "Versatility": score_mapping.get(rating[7], -1),
        "F2P score": score_mapping.get(rating[10], -1),
    }
    return ratings

# %%
import re
import json

def parse_json_safe(player_cards, llm_response, llm_name, with_context: bool):
    player_tag = player_cards.tag[1:]
    deck_cards = player_cards.deck_cards
    deleted_cards = player_cards.deleted_cards or []

    try:
        s = (llm_response or "").strip()

        m = re.search(r"```(?:json)?\\s*([\\s\\S]*?)\\s*```", s, flags=re.IGNORECASE)
        if m:
            candidate = m.group(1).strip()
        else:
            candidate = s

        first_brace = candidate.find("{")
        first_bracket = candidate.find("[")
        starts = [i for i in (first_brace, first_bracket) if i != -1]
        
        if not starts:
            error_msg = f"! Error de parseo (Usuario: {player_tag}, LLM: {llm_name}, Ctx: {with_context}): No se encontró JSON."
            logging.warning(error_msg)
            return None, error_msg

        start = min(starts)
        end = max(candidate.rfind("}"), candidate.rfind("]"))
        
        if end == -1 or end < start:
            error_msg = f"! Error de parseo (Usuario: {player_tag}, LLM: {llm_name}, Ctx: {with_context}): JSON mal formado."
            logging.warning(error_msg)
            return None, error_msg
            
        candidate = candidate[start:end+1]
        parsed = json.loads(candidate)

        if isinstance(parsed, dict):
            parsed["user_id"] = player_tag
            parsed["deleted"] = list(map(lambda c: c.name, deleted_cards))
            parsed["original"] = list(map(lambda c: c.name, deck_cards))
            parsed["llm"] = llm_name
            parsed["with_context"] = with_context
        else:
            parsed = {
                "user_id": player_tag,
                "data": parsed,
                "deleted": list(map(lambda c: c.name, deleted_cards)),
                "llm": llm_name,
                "with_context": with_context
            }

        original_deck_rating_string = fetch_deck_rating(parsed["original"] + parsed["deleted"])
        selected_deck_rating_string = fetch_deck_rating(parsed["original"] + parsed["seleccion"])

        original_deck_ratings = process_deck_rating(original_deck_rating_string)
        selected_deck_ratings = process_deck_rating(selected_deck_rating_string)

        parsed["original_deck_rating"] = original_deck_ratings
        parsed["selected_deck_rating"] = selected_deck_ratings

        total_original_deck_rating = sum(original_deck_ratings.values())
        total_selected_deck_rating = sum(selected_deck_ratings.values())

        parsed["total_original_deck_rating"] = total_original_deck_rating
        parsed["total_selected_deck_rating"] = total_selected_deck_rating

        parsed["was_improved"] = total_selected_deck_rating >= total_original_deck_rating

        return parsed, None

    except json.JSONDecodeError as e:
        error_msg = f"X Error JSONDecode (Usuario: {player_tag}, LLM: {llm_name}, Ctx: {with_context}): {e}"
        logging.error(error_msg)
        return None, error_msg
    except Exception as e:
        error_msg = f"! Error inesperado (Usuario: {player_tag}, LLM: {llm_name}, Ctx: {with_context}): {e}"
        logging.error(error_msg)
        return None, error_msg

# %%
def write_prompt_file(string, user_id):
    with open(f"final_prompts/user_{user_id}.txt", "w", encoding="utf-8") as f:
        f.write(string)

# %%
async def process_user_recommendation(
    llm, 
    player_cards, 
    system_prompt_str, 
    human_prompt_context_str,
    human_prompt_no_context_str,
    with_context: bool,
    valid_f,
    raw_f,
    file_lock
):
    player_tag = player_cards.tag[1:]
    available_cards = player_cards.available_cards
    deck_cards = player_cards.deck_cards

    available_cards_json = json.dumps(list(map(lambda c: c.name, available_cards)))
    deck_cards_json = json.dumps(list(map(lambda c: c.name, deck_cards)))

    try:
        if with_context:
            string_top_decks = "<Top 5 Decks para usar con cada una de las CARTAS_DISPONIBLES>\\n"
            
            for card in deck_cards:
                card_name = card.name
                string_top_decks += f'  <CardGroup name="{card_name}">\\n'
                decks_for_card = top_decks_per_card.get(card_name, {}) 
                for deck_key in decks_for_card.keys():
                    deck_list = decks_for_card[deck_key]
                    string_top_decks += "    <Deck>\\n"
                    for individual_card_name in deck_list:
                        string_top_decks += f'      <Card>{individual_card_name.strip()}</Card>\\n'
                    string_top_decks += "    </Deck>\\n"
                string_top_decks += f'  </CardGroup>\\n'
            string_top_decks += "</TopDecks>"

            rendered_human_prompt = human_prompt_context_str.format(
                TOP_DECKS=string_top_decks,
                CARTAS_DISPONIBLES=available_cards_json,
                CARTAS_SELECCIONADAS=deck_cards_json
            )
        else:
            rendered_human_prompt = human_prompt_no_context_str.format(
                CARTAS_DISPONIBLES=available_cards_json,
                CARTAS_SELECCIONADAS=deck_cards_json
            )
        
        prompt_filename_tag = f"{player_tag}{'_ctx' if with_context else '_noctx'}"
        write_prompt_file(rendered_human_prompt, prompt_filename_tag)

    except Exception as e:
        logging.error(f"! Error al renderizar prompt para usuario {player_tag} (Ctx: {with_context}): {e}")
        return False

    messages = [
        SystemMessage(content=system_prompt_str),
        HumanMessage(content=rendered_human_prompt),
    ]

    try:
        ai_msg = await llm.instance.ainvoke(messages)
        response_content = ai_msg.content

        parsed_result, parse_error = parse_json_safe(player_cards, response_content, llm.name, with_context)
        
        raw_log_data = {
            "user_id": player_tag,
            "llm": llm.name,
            "with_context": with_context,
            "raw_response": response_content,
            "parsed_successfully": (parsed_result is not None),
            "parse_error": parse_error
        }

        async with file_lock:
            raw_f.write(json.dumps(raw_log_data, ensure_ascii=False) + '\n')
            raw_f.flush()
            
            if parsed_result:
                valid_f.write(json.dumps(parsed_result, ensure_ascii=False) + '\n')
                valid_f.flush()

        if parsed_result:
            logging.info(f"Éxito: Usuario {player_tag} (LLM: {llm.name}, Ctx: {with_context})")
            return True
        else:
            return False

    except Exception as e:
        logging.error(f"! Error API (Usuario: {player_tag}, LLM: {llm.name}, Ctx: {with_context}): {e}")
        raw_log_data = {
            "user_id": player_tag,
            "llm": llm.name,
            "with_context": with_context,
            "raw_response": None,
            "parsed_successfully": False,
            "parse_error": f"API Error: {e}"
        }
        async with file_lock:
            raw_f.write(json.dumps(raw_log_data, ensure_ascii=False) + '\n')
            raw_f.flush()
            
        return False

# %%
def generate_human_prompt(human_prompt_template, top_decks, available_cards, selected_cards):
    rendered_human_prompt = human_prompt_template.format(
        TOP_DECKS=top_decks,
        CARTAS_DISPONIBLES=available_cards,
        CARTAS_SELECCIONADAS=selected_cards
    )
    return rendered_human_prompt

# %%
def shuffle_and_remove_cards(player_cards_list, num_to_remove=4):
    updated_player_cards_list = []
    for player_cards in player_cards_list:
        
        available_copy = list(player_cards.available_cards)
        selected_copy = list(player_cards.deck_cards)

        shuffle(available_copy)
        shuffle(selected_copy)

        to_delete = selected_copy[-num_to_remove:]
        selected_for_prompt = selected_copy[:-num_to_remove]

        updated_player_cards = PlayerCards(
            tag=player_cards.tag,
            available_cards=available_copy,
            deck_cards=selected_for_prompt,
            deleted_cards=to_delete
        )
        updated_player_cards_list.append(updated_player_cards)
    
    return updated_player_cards_list

# %%
import time

async def run_all_models_async(
    player_cards_list, 
    models_list,
    system_prompt_str, 
    human_prompt_context_str,
    human_prompt_no_context_str,
    batch_size=50, 
    num_batches=None,
    starting_card_number=4
):
    """
    Orquesta la ejecución asíncrona para todos los LLMs y usuarios,
    controlando el tamaño de los lotes y guardando los resultados en JSONL.
    """
    selected_player_cards_list = shuffle_and_remove_cards(
        player_cards_list, 
        num_to_remove= 8 - starting_card_number
    )

    if num_batches is not None:
        total_to_process = batch_size * num_batches
        players_to_process = selected_player_cards_list[:total_to_process]
    else:
        players_to_process = selected_player_cards_list

    logging.info(f"Iniciando procesamiento para {len(players_to_process)} jugadores a través de {len(models_list)} LLMs (x2 con/sin contexto).")

    output_timestamp = time.strftime('%Y%m%d_%H%M%S')
    valid_results_filename = f"results/valid_results_{output_timestamp}.jsonl"
    raw_results_filename = f"results/raw_results_{output_timestamp}.jsonl"
    
    file_lock = asyncio.Lock()
    
    with open(valid_results_filename, 'a', encoding='utf-8') as valid_f, \
         open(raw_results_filename, 'a', encoding='utf-8') as raw_f:

        all_tasks = []
        for llm in models_list:
            logging.info(f"Creando tareas para: {llm.name}...")
            for player_cards in players_to_process:
                for with_context_flag in [True, False]:
                    task = process_user_recommendation(
                        llm,
                        player_cards, 
                        system_prompt_str, 
                        human_prompt_context_str,
                        human_prompt_no_context_str,
                        with_context_flag,
                        valid_f,
                        raw_f,
                        file_lock
                    )
                    all_tasks.append(task)
                
        logging.info(f"Total de tareas creadas: {len(all_tasks)}")
        
        all_results = []
        total_batches = (len(all_tasks) + batch_size - 1) // batch_size
        
        for i in range(0, len(all_tasks), batch_size):
            current_batch_num = (i // batch_size) + 1
            batch_tasks = all_tasks[i:i + batch_size]
            logging.info(f"\n--- Ejecutando Lote {current_batch_num} / {total_batches} (Tamaño: {len(batch_tasks)}) ---")
            
            batch_results = await asyncio.gather(*batch_tasks, return_exceptions=True)
            all_results.extend(batch_results)
            
            for idx, result in enumerate(batch_results):
                if isinstance(result, Exception):
                    logging.error(f"! Excepción en tarea del lote {current_batch_num}: {result}")
            
            await asyncio.sleep(1) 

    logging.info("\n--- Procesamiento de lotes completado. ---")
    
    valid_count = sum(1 for r in all_results if r is True)
    logging.info(f"Resultados válidos (parseados y guardados): {valid_count} de {len(all_tasks)}")

    return valid_results_filename, raw_results_filename

# %%
import time

models_to_run = [
    llm_gpt3,
    llm_gpt4o,
    llm_gpt5,
    #llm_grok_adapter,
    llm_deepseek_adapter,
    llm_llama_adapter,
]

BATCH_SIZE = 15
NUM_BATCHES = 10

logging.info("Iniciando la ejecución asíncrona...")

valid_filename, raw_filename = await run_all_models_async(
    player_cards_list=player_cards_list,
    models_list=models_to_run,
    system_prompt_str=system_prompt,
    human_prompt_context_str=human_prompt_context,
    human_prompt_no_context_str=human_prompt_no_context,
    batch_size=BATCH_SIZE,
    num_batches=NUM_BATCHES
)

logging.info(f"Ejecución finalizada.")
logging.info(f"Resultados válidos guardados en: '{valid_filename}'")
logging.info(f"Resultados crudos guardados en: '{raw_filename}'")

output_filename = valid_filename
# Out:
# 2025-11-02 18:27:24,603 - root - INFO - Iniciando la ejecución asíncrona...
# 2025-11-02 18:27:25,603 - root - INFO - Iniciando procesamiento para 150 jugadores a través de 5 LLMs (x2 con/sin contexto).
# 2025-11-02 18:27:25,604 - root - INFO - Creando tareas para: gpt-35-turbo...
# 2025-11-02 18:27:25,604 - root - INFO - Creando tareas para: gpt-4o...
# 2025-11-02 18:27:25,604 - root - INFO - Creando tareas para: gpt-5-chat...
# 2025-11-02 18:27:25,605 - root - INFO - Creando tareas para: DeepSeek-V3.1...
# 2025-11-02 18:27:25,605 - root - INFO - Creando tareas para: Llama-3.3-70B-Instruct...
# 2025-11-02 18:27:25,605 - root - INFO - Total de tareas creadas: 1500
# 2025-11-02 18:27:25,605 - root - INFO -
# --- Ejecutando Lote 1 / 100 (Tamaño: 15) ---
# 2025-11-02 18:27:31,501 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:27:34,446 - root - INFO - Éxito: Usuario VL0QCY9R8 (LLM: gpt-35-turbo, Ctx: False)
# 2025-11-02 18:27:34,447 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:27:34,448 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:27:34,448 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:27:34,449 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:27:36,379 - root - ERROR - ! Error inesperado (Usuario: 2G22QVP89, LLM: gpt-35-turbo, Ctx: False): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=ElectroSpirit-FlyingMachine-GoldenKnight-SkellyBarrel-GobGang-Inferno-Fireball-Minions-IceSpirit-Archers-Zap
# 2025-11-02 18:27:38,633 - root - ERROR - ! Error inesperado (Usuario: CRY0RPU, LLM: gpt-35-turbo, Ctx: False): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=Tesla-Firecracker-Barrel-SkeletonKing-Inferno-Horde-Fireball-GobGang-IceSpirit-Barrel-Tesla-Firecracker
# 2025-11-02 18:27:40,013 - root - ERROR - ! Error inesperado (Usuario: VL0QCY9R8, LLM: gpt-35-turbo, Ctx: True): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=Firecracker-Bats-Skellies-SkellyBarrel-GobGang-InfernoD-Zap-Miner-MegaKnight-Bats-Poison-GobHut
# 2025-11-02 18:27:42,319 - root - ERROR - ! Error inesperado (Usuario: L0092LLGP, LLM: gpt-35-turbo, Ctx: True): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=MegaKnight-SpearGobs-Bats-Skellies-InfernoD-Miner-Gobs-Zap-GobHut-Poison-GobGang-MegaKnight
# 2025-11-02 18:27:42,325 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:27:42,327 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:27:42,328 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:27:42,330 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:27:42,331 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:27:42,332 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:27:42,333 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:27:42,333 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:27:42,334 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:27:42,335 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:27:45,353 - root - ERROR - ! Error inesperado (Usuario: LU2QQJU0Y, LLM: gpt-35-turbo, Ctx: False): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=eWiz-Hog-Exe-Log-Inferno-Fireball-Minions-IceSpirit-GobGang-Barrel-Zap-GoblinMachine
# 2025-11-02 18:27:47,662 - root - ERROR - ! Error inesperado (Usuario: L0092LLGP, LLM: gpt-35-turbo, Ctx: False): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=MegaKnight-SpearGobs-Bats-Skellies-GobGang-Fireball-eWiz-InfernoD-Zap-Minions-BarbBarrel-Tornado
# 2025-11-02 18:27:52,360 - root - ERROR - ! Error inesperado (Usuario: UL98CLGP, LLM: gpt-35-turbo, Ctx: False): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=BombTower-Knight-Miner-Log-eWiz-Inferno-Fireball-GobGang-Minions-Barrel-IceSpirit-GoblinDrill
# 2025-11-02 18:27:55,384 - root - ERROR - ! Error inesperado (Usuario: 999QV8RJU, LLM: gpt-35-turbo, Ctx: False): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=WallBreakers-Miner-Cannon-Bats-GobGang-Inferno-Fireball-MM-Zap-Barrel-GoblinDrill-GobHut
# 2025-11-02 18:27:59,534 - root - ERROR - ! Error inesperado (Usuario: 2G22QVP89, LLM: gpt-35-turbo, Ctx: True): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=ElectroSpirit-FlyingMachine-GoldenKnight-SkellyBarrel-GobHut-Log-MegaKnight-Zap-Bats-InfernoD-Poison-GobGang
# 2025-11-02 18:28:03,003 - root - ERROR - ! Error inesperado (Usuario: RCV90RLVC, LLM: gpt-35-turbo, Ctx: True): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=Tombstone-GobGang-SkellyBarrel-Log-Minions-Fireball-Balloon-InfernoD-Lava-Zap-Skarmy-NightWitch
# 2025-11-02 18:28:06,178 - root - ERROR - ! Error inesperado (Usuario: 999QV8RJU, LLM: gpt-35-turbo, Ctx: True): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=WallBreakers-Miner-Cannon-Bats-GobGang-Zap-InfernoD-Witch-MegaKnight-Musk-Fireball-RoyalDelivery
# 2025-11-02 18:28:08,628 - root - ERROR - ! Error inesperado (Usuario: LU2QQJU0Y, LLM: gpt-35-turbo, Ctx: True): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=eWiz-Hog-Exe-Log-Inferno-IceGolem-Fireball-IceSpirit-Guards-Miner-Phoenix-Prince
# 2025-11-02 18:28:12,322 - root - ERROR - ! Error inesperado (Usuario: UL98CLGP, LLM: gpt-35-turbo, Ctx: True): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=BombTower-Knight-Miner-Log-GobGang-MM-Fireball-GoblinDrill-Barrel-GobHut-GoblinMachine-GoblinDemolisher
# 2025-11-02 18:28:15,408 - root - ERROR - ! Error inesperado (Usuario: CRY0RPU, LLM: gpt-35-turbo, Ctx: True): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=Tesla-Firecracker-Barrel-SkeletonKing-Log-XBow-Earthquake-Mortar-Skellies-IceSpirit-BombTower-LittlePrince
# 2025-11-02 18:28:16,414 - root - INFO -
# --- Ejecutando Lote 2 / 100 (Tamaño: 15) ---
# 2025-11-02 18:28:21,735 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:28:23,326 - root - INFO - Éxito: Usuario RLVLPLLRU (LLM: gpt-35-turbo, Ctx: False)
# 2025-11-02 18:28:23,327 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:28:23,328 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:28:25,937 - root - INFO - Éxito: Usuario UP80QCJJV (LLM: gpt-35-turbo, Ctx: False)
# 2025-11-02 18:28:27,321 - root - ERROR - ! Error inesperado (Usuario: L9PLR988J, LLM: gpt-35-turbo, Ctx: False): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=Archers-Valk-Fireball-Hog-MM-Fireball-Cannon-GobGang-Barrel-GoblinDrill-GobGang-GobGang
# 2025-11-02 18:28:27,325 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:28:27,326 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:28:27,327 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:28:27,328 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:28:27,329 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:28:27,330 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:28:27,335 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:28:27,336 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:28:27,337 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:28:27,338 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:28:27,340 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:28:27,341 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:28:30,289 - root - ERROR - ! Error inesperado (Usuario: G2J898UJ0, LLM: gpt-35-turbo, Ctx: False): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=Fireball-Snowball-Zappies-PEKKA-InfernoD-Minions-GobGang-Fireball-Snowball-Zappies-PEKKA
# 2025-11-02 18:28:35,064 - root - ERROR - ! Error inesperado (Usuario: 9JL9080GL, LLM: gpt-35-turbo, Ctx: True): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=Valk-Witch-Bats-Golem-NightWitch-Poison-MM-Lumber-BabyD-BarbBarrel-Golem-Zap
# 2025-11-02 18:28:38,065 - root - ERROR - ! Error inesperado (Usuario: L9PLR988J, LLM: gpt-35-turbo, Ctx: True): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=Archers-Valk-Fireball-Hog-Tesla-Skellies-Fireball-IceGolem-Cannon-Musk-Zap-IceSpirit
# 2025-11-02 18:28:42,017 - root - ERROR - ! Error inesperado (Usuario: YC9RRVYYL, LLM: gpt-35-turbo, Ctx: True): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=GoblinCage-RoyalHogs-BarbBarrel-ElectroSpirit-GobGang-Zappies-Fireball-Snowball-MM-Hunter-RG-FireSpirit
# 2025-11-02 18:28:44,988 - root - ERROR - ! Error inesperado (Usuario: UP80QCJJV, LLM: gpt-35-turbo, Ctx: True): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=RoyalDelivery-Bowler-MP-Hog-Log-MegaKnight-Gobs-Earthquake-Mortar-Musk-Tornado-Poison
# 2025-11-02 18:28:47,217 - root - ERROR - ! Error inesperado (Usuario: YC9RRVYYL, LLM: gpt-35-turbo, Ctx: False): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=GoblinCage-RoyalHogs-BarbBarrel-ElectroSpirit-GobGang-Inferno-Fireball-IceSpirit-Zap
# 2025-11-02 18:28:52,747 - root - ERROR - ! Error inesperado (Usuario: PUY89YPL8, LLM: gpt-35-turbo, Ctx: False): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=Rocket-Gobs-Valk-Hog-Fireball-GobGang-Inferno-Minions-Archers-Zap-IceSpirit-Cannon
# 2025-11-02 18:28:55,519 - root - ERROR - ! Error inesperado (Usuario: RLVLPLLRU, LLM: gpt-35-turbo, Ctx: True): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=Tesla-MegaKnight-Minions-Guards-GobGiant-Firecracker-Barrel-Zap-GobGang-GoblinDrill-GobHut-GoblinCurse
# 2025-11-02 18:28:57,982 - root - ERROR - ! Error inesperado (Usuario: 9JL9080GL, LLM: gpt-35-turbo, Ctx: False): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=Valk-Witch-Bats-Golem-eDragon-Tornado-MM-Fireball-GobGang-Zap-Fisherman-Bats
# 2025-11-02 18:29:01,269 - root - ERROR - ! Error inesperado (Usuario: PUY89YPL8, LLM: gpt-35-turbo, Ctx: True): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=Rocket-Gobs-Valk-Hog-Zap-GobGang-Inferno-IceSpirit-Barrel-Princess-Miner-IceGolem
# 2025-11-02 18:29:04,444 - root - ERROR - ! Error inesperado (Usuario: RCV90RLVC, LLM: gpt-35-turbo, Ctx: False): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=Tombstone-GobGang-SkellyBarrel-Log-eWiz-Fireball-GobGang-MM-IceGolem-Hunter-Earthquake-RoyalHogs
# 2025-11-02 18:29:07,110 - root - ERROR - ! Error inesperado (Usuario: G2J898UJ0, LLM: gpt-35-turbo, Ctx: True): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=Fireball-Snowball-Zappies-PEKKA-eWiz-GobGiant-GoblinCage-GoblinDrill-Barrel-GobGang-GoblinCurse-GoblinDemolisher
# 2025-11-02 18:29:08,115 - root - INFO -
# --- Ejecutando Lote 3 / 100 (Tamaño: 15) ---
# 2025-11-02 18:29:13,452 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:29:15,638 - root - INFO - Éxito: Usuario U9QUY9Y2Y (LLM: gpt-35-turbo, Ctx: False)
# 2025-11-02 18:29:15,639 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:29:15,640 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:29:15,641 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:29:18,220 - root - INFO - Éxito: Usuario CVRURLY0U (LLM: gpt-35-turbo, Ctx: False)
# 2025-11-02 18:29:19,788 - root - INFO - Éxito: Usuario JGL0Y00PG (LLM: gpt-35-turbo, Ctx: False)
# 2025-11-02 18:29:23,084 - root - ERROR - ! Error inesperado (Usuario: UQGLCV92C, LLM: gpt-35-turbo, Ctx: True): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=Firecracker-Bats-Skarmy-Hog-GobGang-WallBreakers-Arrows-GoblinDrill-Knight-IceSpirit-Poison-Inferno
# 2025-11-02 18:29:23,090 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:29:23,092 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:29:23,093 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:29:23,095 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:29:23,096 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:29:23,098 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:29:23,099 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:29:23,100 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:29:23,101 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:29:23,102 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:29:23,103 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:29:26,824 - root - ERROR - ! Error inesperado (Usuario: JG80PL8GY, LLM: gpt-35-turbo, Ctx: False): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=Lumber-Log-Wiz-DartGob-Inferno-Minions-Fireball-GobGang-eWiz-Barrel-GoblinDrill-GobGiant
# 2025-11-02 18:29:29,682 - root - ERROR - ! Error inesperado (Usuario: JG80PL8GY, LLM: gpt-35-turbo, Ctx: True): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=Lumber-Log-Wiz-DartGob-Archers-IceSpirit-MM-GobGang-Prince-WallBreakers-Fireball-Barrel
# 2025-11-02 18:29:34,177 - root - ERROR - ! Error inesperado (Usuario: YV0R229CY, LLM: gpt-35-turbo, Ctx: True): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=MagicArcher-GobGiant-Log-Ghost-Prince-Fireball-Bats-DarkPrince-BarbBarrel-Zappies-GobGiant-GobGang
# 2025-11-02 18:29:37,314 - root - ERROR - ! Error inesperado (Usuario: RJQ2VPGY, LLM: gpt-35-turbo, Ctx: True): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=Valk-Exe-Gobs-Tornado-ElectroSpirit-Log-Skellies-Fisherman-IceSpirit-Hog-Exe-Gobs
# 2025-11-02 18:29:40,296 - root - ERROR - ! Error inesperado (Usuario: JGL0Y00PG, LLM: gpt-35-turbo, Ctx: True): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=Skarmy-Miner-SkeletonKing-WallBreakers-GobGang-Zap-Inferno-Horde-IceGolem-MM-Log-Fireball
# 2025-11-02 18:29:43,777 - root - ERROR - ! Error inesperado (Usuario: U9QUY9Y2Y, LLM: gpt-35-turbo, Ctx: True): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=Poison-Mortar-Gobs-Miner-Pump-IceSpirit-MM-MegaKnight-NightWitch-Giant-Zap-Miner
# 2025-11-02 18:29:46,240 - root - ERROR - ! Error inesperado (Usuario: CVRURLY0U, LLM: gpt-35-turbo, Ctx: True): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=eWiz-GobGiant-Lumber-eBarbs-Inferno-Log-IceGolem-Fireball-IceSpirit-Guards-MM
# 2025-11-02 18:29:51,256 - root - ERROR - ! Error inesperado (Usuario: LQJJY882P, LLM: gpt-35-turbo, Ctx: False): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=Valk-Furnace-Witch-BabyD-Inferno-Minions-Fireball-GobGang-Zap-MM-Barbs-Poison
# 2025-11-02 18:29:54,416 - root - ERROR - ! Error inesperado (Usuario: YV0R229CY, LLM: gpt-35-turbo, Ctx: False): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=MagicArcher-GobGiant-Log-Ghost-GobGang-Inferno-Fireball-Minions-Zap-IceGolem-MM-ElixirGolem
# 2025-11-02 18:29:56,924 - root - ERROR - ! Error inesperado (Usuario: LQJJY882P, LLM: gpt-35-turbo, Ctx: True): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=Valk-Furnace-Witch-BabyD-Tombstone-Fireball-RoyalHogs-Zappies-MM-MagicArcher-Valk-IceSpirit
# 2025-11-02 18:30:00,347 - root - ERROR - ! Error inesperado (Usuario: UQGLCV92C, LLM: gpt-35-turbo, Ctx: False): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=Firecracker-Bats-Skarmy-Hog-MM-Fireball-Cannon-GobGang-Tornado-Valk-Zap-GoblinCage
# 2025-11-02 18:30:01,352 - root - INFO -
# --- Ejecutando Lote 4 / 100 (Tamaño: 15) ---
# 2025-11-02 18:30:08,236 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:30:09,895 - root - INFO - Éxito: Usuario 88YYYYC2C (LLM: gpt-35-turbo, Ctx: False)
# 2025-11-02 18:30:09,896 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:30:09,897 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:30:09,897 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:30:12,591 - root - INFO - Éxito: Usuario 920QQLL0G (LLM: gpt-35-turbo, Ctx: False)
# 2025-11-02 18:30:14,337 - root - ERROR - ! Error inesperado (Usuario: Q0QG2VPG, LLM: gpt-35-turbo, Ctx: True): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=Arrows-Prince-Knight-BabyD-MM-Giant-Snowball-DarkPrince-Gobs-Fireball-MP-Archers
# 2025-11-02 18:30:16,484 - root - INFO - Éxito: Usuario 8PVPJ8LCR (LLM: gpt-35-turbo, Ctx: False)
# 2025-11-02 18:30:16,485 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:30:16,486 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:30:16,486 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:30:16,487 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:30:16,487 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:30:16,488 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:30:16,488 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:30:16,490 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:30:16,490 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:30:16,490 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:30:16,491 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:30:19,298 - root - ERROR - ! Error inesperado (Usuario: C09PQGURR, LLM: gpt-35-turbo, Ctx: False): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=DartGob-Barrel-Firecracker-Tesla-GobGang-Horde-Inferno-Fireball-IceSpirit-Barrel-DartGob-Tesla
# 2025-11-02 18:30:22,933 - root - ERROR - ! Error inesperado (Usuario: 920QQLL0G, LLM: gpt-35-turbo, Ctx: True): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=Hog-Bomber-MP-BabyD-GobGang-Inferno-Fireball-Zap-IceSpirit-IceGolem-Log-eWiz
# 2025-11-02 18:30:25,268 - root - ERROR - ! Error inesperado (Usuario: Q0QG2VPG, LLM: gpt-35-turbo, Ctx: False): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=Arrows-Prince-Knight-BabyD-GobGang-MM-Fireball-Tornado-Barrel-Inferno-IceSpirit-Zap
# 2025-11-02 18:30:29,744 - root - ERROR - ! Error inesperado (Usuario: 9RCPLY98J, LLM: gpt-35-turbo, Ctx: False): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=Arrows-Ghost-GoblinCage-RoyalRecruits-GobGiant-InfernoD-Fireball-GobGang-Minions-Zap-BarbBarrel-Poison
# 2025-11-02 18:30:32,714 - root - ERROR - ! Error inesperado (Usuario: 8PVPJ8LCR, LLM: gpt-35-turbo, Ctx: True): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=Firecracker-GobGang-eWiz-MegaKnight-InfernoD-Poison-GobGang-Zap-Bats-Prince-Miner-Barrel
# 2025-11-02 18:30:35,878 - root - ERROR - ! Error inesperado (Usuario: 9RCPLY98J, LLM: gpt-35-turbo, Ctx: True): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=Arrows-Ghost-GoblinCage-RoyalRecruits-GoblinCage-ElectroGiant-DarkPrince-Tornado-Lightning-BarbBarrel-Exe-NightWitch
# 2025-11-02 18:30:38,345 - root - ERROR - ! Error inesperado (Usuario: RJQ2VPGY, LLM: gpt-35-turbo, Ctx: False): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=Valk-Exe-Gobs-Tornado-Fireball-MM-IceSpirit-GobGang-Barrel-GoblinDrill-GobGang-GobGang
# 2025-11-02 18:30:43,900 - root - ERROR - ! Error inesperado (Usuario: JL2VP9CJ2, LLM: gpt-35-turbo, Ctx: True): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=MP-Lightning-NightWitch-eDragon-GobGang-Tombstone-Minions-Zap-MM-Lava-Balloon-BarbBarrel
# 2025-11-02 18:30:45,992 - root - ERROR - ! Error inesperado (Usuario: 88YYYYC2C, LLM: gpt-35-turbo, Ctx: True): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=Furnace-Monk-Poison-GobHut-eWiz-GobGang-RG-Fireball-MM-Log-BarbBarrel-BabyD
# 2025-11-02 18:30:49,263 - root - ERROR - ! Error inesperado (Usuario: JL2VP9CJ2, LLM: gpt-35-turbo, Ctx: False): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=MP-Lightning-NightWitch-eDragon-GobGang-Fireball-Zap-eWiz-GoblinDrill-GobGiant-BarbBarrel-GoblinCage
# 2025-11-02 18:30:51,979 - root - ERROR - ! Error inesperado (Usuario: C09PQGURR, LLM: gpt-35-turbo, Ctx: True): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=DartGob-Barrel-Firecracker-Tesla-Rascals-Log-Princess-GobGang-Rocket-Knight-Tombstone-IceSpirit
# 2025-11-02 18:30:52,986 - root - INFO -
# --- Ejecutando Lote 5 / 100 (Tamaño: 15) ---
# 2025-11-02 18:30:57,597 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:31:00,117 - root - INFO - Éxito: Usuario R28L8QLG (LLM: gpt-35-turbo, Ctx: True)
# 2025-11-02 18:31:00,119 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:31:01,961 - root - INFO - Éxito: Usuario Q2GQQ2U2Y (LLM: gpt-35-turbo, Ctx: False)
# 2025-11-02 18:31:01,962 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:31:01,963 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:31:01,964 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:31:01,965 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:31:01,966 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:31:04,094 - root - INFO - Éxito: Usuario QPJRPGL9 (LLM: gpt-35-turbo, Ctx: True)
# 2025-11-02 18:31:07,426 - root - ERROR - ! Error inesperado (Usuario: R28L8QLG, LLM: gpt-35-turbo, Ctx: False): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=Freeze-Tesla-Balloon-BarbBarrel-InfernoD-Minions-Fireball-GobGang-GoblinDrill-GoblinCage-Zap
# 2025-11-02 18:31:11,215 - root - ERROR - ! Error inesperado (Usuario: 8YR20RY90, LLM: gpt-35-turbo, Ctx: True): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=MP-Gobs-Tornado-IceSpirit-Exe-Witch-Ghost-Arrows-Knight-Valk-Poison-Gobs
# 2025-11-02 18:31:14,595 - root - ERROR - ! Error inesperado (Usuario: JUP9RVC2Q, LLM: gpt-35-turbo, Ctx: True): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=Firecracker-Barrel-Cannon-DartGob-Log-GobGang-Tornado-GoblinDrill-Knight-BombTower-HealSpirit-Arrows
# 2025-11-02 18:31:18,300 - root - ERROR - ! Error inesperado (Usuario: 2QGGY0VL, LLM: gpt-35-turbo, Ctx: False): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=DartGob-Firecracker-MotherWitch-HealSpirit-GobGang-Barrel-GoblinDrill-GobGiant-GobHut-GoblinCage-GoblinDemolisher-Goblinstein
# 2025-11-02 18:31:18,307 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:31:18,309 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:31:18,310 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:31:18,311 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:31:18,312 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:31:18,313 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:31:18,314 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:31:18,315 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:31:22,685 - root - ERROR - ! Error inesperado (Usuario: 8YR20RY90, LLM: gpt-35-turbo, Ctx: False): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=MP-Gobs-Tornado-IceSpirit-GobGang-Fireball-MM-Hunter-Barrel-GoblinDrill-Zap-Inferno
# 2025-11-02 18:31:26,355 - root - ERROR - ! Error inesperado (Usuario: P282292Y, LLM: gpt-35-turbo, Ctx: True): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=GoldenKnight-Miner-Minions-Guards-GoblinDrill-Skellies-Tornado-MagicArcher-eWiz-Miner-Minions-Guards
# 2025-11-02 18:31:28,317 - root - ERROR - ! Error inesperado (Usuario: QPJRPGL9, LLM: gpt-35-turbo, Ctx: False): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=Furnace-RamRider-Skarmy-Tornado-Inferno-MM-Fireball-GobGang-eWiz-Barrel-Zap-GoblinDrill
# 2025-11-02 18:31:31,341 - root - ERROR - ! Error inesperado (Usuario: Q2GQQ2U2Y, LLM: gpt-35-turbo, Ctx: True): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=Cannon-Musk-Skellies-Log-RoyalDelivery-ArcherQueen-FireSpirit-RoyalHogs-Earthquake-GobGang-Log-MM
# 2025-11-02 18:31:35,485 - root - ERROR - ! Error inesperado (Usuario: 90R0GR29, LLM: gpt-35-turbo, Ctx: True): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=Log-Skarmy-ArcherQueen-Berserker-GobGang-Fireball-Barrel-GoblinDrill-SpearGobs-Tornado-Log-Skarmy
# 2025-11-02 18:31:38,661 - root - ERROR - ! Error inesperado (Usuario: 2QGGY0VL, LLM: gpt-35-turbo, Ctx: True): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=DartGob-Firecracker-MotherWitch-HealSpirit-GobGang-Log-Barrel-Fireball-SkeletonKing-Wiz-WallBreakers-IceSpirit
# 2025-11-02 18:31:41,946 - root - ERROR - ! Error inesperado (Usuario: JUP9RVC2Q, LLM: gpt-35-turbo, Ctx: False): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=Firecracker-Barrel-Cannon-DartGob-Inferno-Minions-Fireball-GobGang-GobGiant-GoblinDrill-GobHut-GoblinCage
# 2025-11-02 18:31:45,008 - root - ERROR - ! Error inesperado (Usuario: 90R0GR29, LLM: gpt-35-turbo, Ctx: False): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=Log-Skarmy-ArcherQueen-Berserker-GobGang-Fireball-MP-Tornado-Horde-Cannon-Zap
# 2025-11-02 18:31:46,014 - root - INFO -
# --- Ejecutando Lote 6 / 100 (Tamaño: 15) ---
# 2025-11-02 18:31:51,209 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:31:52,808 - root - INFO - Éxito: Usuario P282292Y (LLM: gpt-35-turbo, Ctx: False)
# 2025-11-02 18:31:52,809 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:31:52,810 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:31:52,810 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:31:52,811 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:31:54,677 - root - INFO - Éxito: Usuario PPC82JJU0 (LLM: gpt-35-turbo, Ctx: False)
# 2025-11-02 18:31:57,826 - root - INFO - Éxito: Usuario QP2CULJR8 (LLM: gpt-35-turbo, Ctx: False)
# 2025-11-02 18:32:00,629 - root - INFO - Éxito: Usuario RU0QVL8PV (LLM: gpt-35-turbo, Ctx: False)
# 2025-11-02 18:32:03,291 - root - ERROR - ! Error inesperado (Usuario: UJGLJY9L9, LLM: gpt-35-turbo, Ctx: False): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=Tombstone-Log-Barrel-GiantSkelly-eWiz-Fireball-GobGang-InfernoD-Minions-Zap-IceSpirit-Hunter
# 2025-11-02 18:32:03,297 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:32:03,298 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:32:03,299 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:32:03,300 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:32:03,302 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:32:03,303 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:32:03,304 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:32:03,305 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:32:03,306 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:32:03,307 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:32:06,336 - root - ERROR - ! Error inesperado (Usuario: PPC82JJU0, LLM: gpt-35-turbo, Ctx: True): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=Ram-Zap-Ghost-PEKKA-Bandit-Musk-GobGang-BarbBarrel-Poison-Horde-Tornado-IceWiz
# 2025-11-02 18:32:10,608 - root - ERROR - ! Error inesperado (Usuario: 2Y0QLR82Y, LLM: gpt-35-turbo, Ctx: True): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=Inferno-DartGob-Valk-Princess-eWiz-GobGang-Ram-Log-MP-Zap-Bats-InfernoD
# 2025-11-02 18:32:13,597 - root - ERROR - ! Error inesperado (Usuario: QP2CULJR8, LLM: gpt-35-turbo, Ctx: True): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=Archers-Skellies-Wiz-Cannon-Tesla-Fireball-FireSpirit-XBow-Log-IceGolem-MM-Poison
# 2025-11-02 18:32:18,290 - root - ERROR - ! Error inesperado (Usuario: UPUG0VPJ, LLM: gpt-35-turbo, Ctx: True): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=Minions-MegaKnight-Vines-GobGang-IceGolem-Zap-GobHut-Poison-GoblinMachine-GobGiant-Minions-Rage
# 2025-11-02 18:32:22,384 - root - ERROR - ! Error inesperado (Usuario: JVU0LYPJ2, LLM: gpt-35-turbo, Ctx: False): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=SkeletonKing-Musk-BabyD-Graveyard-eWiz-Tornado-Snowball-InfernoD-Fireball-Zap-IceGolem-GobGang
# 2025-11-02 18:32:25,642 - root - ERROR - ! Error inesperado (Usuario: RU0QVL8PV, LLM: gpt-35-turbo, Ctx: True): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=Witch-MP-InfernoD-Valk-FireSpirit-Golem-Poison-Tornado-NightWitch-Gobs-Rage-eBarbs
# 2025-11-02 18:32:28,119 - root - ERROR - ! Error inesperado (Usuario: UJGLJY9L9, LLM: gpt-35-turbo, Ctx: True): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=Tombstone-Log-Barrel-GiantSkelly-Minions-Fireball-Balloon-InfernoD-Lava-Zap-Skarmy-NightWitch
# 2025-11-02 18:32:31,293 - root - ERROR - ! Error inesperado (Usuario: UPUG0VPJ, LLM: gpt-35-turbo, Ctx: False): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=Minions-MegaKnight-Vines-GobGang-Barrel-GoblinDrill-GobGang-GoblinCage-GobGiant-GoblinCurse-GoblinMachine-Goblinstein
# 2025-11-02 18:32:34,263 - root - ERROR - ! Error inesperado (Usuario: 2Y0QLR82Y, LLM: gpt-35-turbo, Ctx: False): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=Inferno-DartGob-Valk-Princess-GobGang-MM-Fireball-Barrel-GobHut-BarbBarrel-GoblinDrill-GoblinCurse
# 2025-11-02 18:32:37,334 - root - ERROR - ! Error inesperado (Usuario: JVU0LYPJ2, LLM: gpt-35-turbo, Ctx: True): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=SkeletonKing-Musk-BabyD-Graveyard-IceWiz-Tombstone-Poison-BarbBarrel-Bats-MM-Fireball-Tornado
# 2025-11-02 18:32:38,341 - root - INFO -
# --- Ejecutando Lote 7 / 100 (Tamaño: 15) ---
# 2025-11-02 18:32:43,774 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:32:46,911 - root - INFO - Éxito: Usuario 882YJ2JJJ (LLM: gpt-35-turbo, Ctx: False)
# 2025-11-02 18:32:46,912 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:32:46,913 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:32:46,914 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:32:48,862 - root - INFO - Éxito: Usuario 8LGCPQUL (LLM: gpt-35-turbo, Ctx: True)
# 2025-11-02 18:32:51,365 - root - ERROR - ! Error inesperado (Usuario: 9G2982PC, LLM: gpt-35-turbo, Ctx: False): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=Poison-Inferno-Bowler-GobGang-Miner-Fireball-Minions-GobGang
# 2025-11-02 18:32:53,718 - root - ERROR - ! Error inesperado (Usuario: Q9L8GYVY2, LLM: gpt-35-turbo, Ctx: False): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=Arrows-SkellyBarrel-Barrel-Firecracker-GobGang-Inferno-Minions-Fireball-Snowball-RoyalDelivery-Hunter-Zap
# 2025-11-02 18:32:53,725 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:32:53,727 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:32:53,728 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:32:53,729 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:32:53,730 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:32:53,731 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:32:53,732 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:32:53,733 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:32:53,735 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:32:53,739 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:32:53,741 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 18:32:56,486 - root - ERROR - ! Error inesperado (Usuario: YPC98P0VC, LLM: gpt-35-turbo, Ctx: False): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=RG-Fisherman-BarbBarrel-Skellies-Inferno-Minions-Fireball-GobGang-Barrel-GoblinDrill-GobHut-GoblinCurse
# 2025-11-02 18:33:00,477 - root - ERROR - ! Error inesperado (Usuario: 22JR9V0U2, LLM: gpt-35-turbo, Ctx: True): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=Wiz-Skarmy-Inferno-MP-eWiz-GobGang-Ram-Knight-Poison-Log-IceSpirit-MP
# 2025-11-02 18:33:04,472 - root - ERROR - ! Error inesperado (Usuario: Y8P2VR29G, LLM: gpt-35-turbo, Ctx: False): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=MegaKnight-Bats-BossBandit-Fireball-InfernoD-GobGang-Zap-GoblinDrill-SkeletonDragons-Firecracker-IceGolem-GoblinCage
# ...
# 2025-11-02 20:12:57,209 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# 2025-11-02 20:12:57,209 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# 2025-11-02 20:12:57,210 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# 2025-11-02 20:12:57,210 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# 2025-11-02 20:12:57,211 - openai._base_client - INFO - Retrying request to /chat/completions in 0.492852 seconds
# 2025-11-02 20:12:57,212 - openai._base_client - INFO - Retrying request to /chat/completions in 0.413558 seconds
# 2025-11-02 20:12:57,213 - openai._base_client - INFO - Retrying request to /chat/completions in 0.476163 seconds
# 2025-11-02 20:12:57,213 - openai._base_client - INFO - Retrying request to /chat/completions in 0.442786 seconds
# 2025-11-02 20:12:57,278 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# 2025-11-02 20:12:57,280 - openai._base_client - INFO - Retrying request to /chat/completions in 0.432634 seconds
# 2025-11-02 20:12:57,717 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# 2025-11-02 20:12:57,718 - openai._base_client - INFO - Retrying request to /chat/completions in 0.950250 seconds
# 2025-11-02 20:12:57,748 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# 2025-11-02 20:12:57,750 - openai._base_client - INFO - Retrying request to /chat/completions in 0.979160 seconds
# 2025-11-02 20:12:57,765 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# 2025-11-02 20:12:57,767 - openai._base_client - INFO - Retrying request to /chat/completions in 0.984583 seconds
# 2025-11-02 20:12:57,769 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# 2025-11-02 20:12:57,771 - openai._base_client - INFO - Retrying request to /chat/completions in 0.847178 seconds
# 2025-11-02 20:12:57,779 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# 2025-11-02 20:12:57,780 - openai._base_client - INFO - Retrying request to /chat/completions in 0.879731 seconds
# 2025-11-02 20:12:57,796 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# 2025-11-02 20:12:57,807 - openai._base_client - INFO - Retrying request to /chat/completions in 0.841209 seconds
# 2025-11-02 20:12:57,811 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# 2025-11-02 20:12:57,826 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# 2025-11-02 20:12:57,837 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# 2025-11-02 20:12:57,841 - openai._base_client - INFO - Retrying request to /chat/completions in 0.931469 seconds
# 2025-11-02 20:12:57,843 - openai._base_client - INFO - Retrying request to /chat/completions in 0.919574 seconds
# 2025-11-02 20:12:57,845 - openai._base_client - INFO - Retrying request to /chat/completions in 0.930928 seconds
# 2025-11-02 20:12:57,846 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# 2025-11-02 20:12:57,848 - openai._base_client - INFO - Retrying request to /chat/completions in 0.782757 seconds
# 2025-11-02 20:12:57,848 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# 2025-11-02 20:12:57,851 - openai._base_client - INFO - Retrying request to /chat/completions in 0.901292 seconds
# 2025-11-02 20:12:57,861 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# 2025-11-02 20:12:57,863 - openai._base_client - INFO - Retrying request to /chat/completions in 0.787557 seconds
# 2025-11-02 20:12:57,869 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# 2025-11-02 20:12:57,871 - openai._base_client - INFO - Retrying request to /chat/completions in 0.854813 seconds
# 2025-11-02 20:12:57,927 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# 2025-11-02 20:12:57,928 - openai._base_client - INFO - Retrying request to /chat/completions in 0.919980 seconds
# 2025-11-02 20:12:58,905 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# Error en el adaptador de OpenAI (Llama-3.3-70B-Instruct): Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to Llama-3.3-70B-Instruct for Llama-3.3-70B-Instruct in East US 2 have exceeded the call rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-05-01-preview. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}
# 2025-11-02 20:12:58,907 - root - WARNING - ! Error de parseo (Usuario: URPQR2P2C, LLM: Llama-3.3-70B-Instruct, Ctx: False): No se encontró JSON.
# 2025-11-02 20:12:58,912 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# Error en el adaptador de OpenAI (Llama-3.3-70B-Instruct): Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to Llama-3.3-70B-Instruct for Llama-3.3-70B-Instruct in East US 2 have exceeded the call rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-05-01-preview. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}
# 2025-11-02 20:12:58,914 - root - WARNING - ! Error de parseo (Usuario: URPQR2P2C, LLM: Llama-3.3-70B-Instruct, Ctx: True): No se encontró JSON.
# 2025-11-02 20:12:58,921 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# Error en el adaptador de OpenAI (Llama-3.3-70B-Instruct): Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to Llama-3.3-70B-Instruct for Llama-3.3-70B-Instruct in East US 2 have exceeded the call rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-05-01-preview. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}
# 2025-11-02 20:12:58,923 - root - WARNING - ! Error de parseo (Usuario: 80UQVQG09, LLM: Llama-3.3-70B-Instruct, Ctx: True): No se encontró JSON.
# 2025-11-02 20:12:58,925 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# Error en el adaptador de OpenAI (Llama-3.3-70B-Instruct): Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to Llama-3.3-70B-Instruct for Llama-3.3-70B-Instruct in East US 2 have exceeded the call rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-05-01-preview. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}
# 2025-11-02 20:12:58,927 - root - WARNING - ! Error de parseo (Usuario: 80UQVQG09, LLM: Llama-3.3-70B-Instruct, Ctx: False): No se encontró JSON.
# 2025-11-02 20:12:58,979 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# Error en el adaptador de OpenAI (Llama-3.3-70B-Instruct): Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to Llama-3.3-70B-Instruct for Llama-3.3-70B-Instruct in East US 2 have exceeded the call rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-05-01-preview. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}
# 2025-11-02 20:12:58,981 - root - WARNING - ! Error de parseo (Usuario: RUQYGQRJ2, LLM: Llama-3.3-70B-Instruct, Ctx: False): No se encontró JSON.
# 2025-11-02 20:12:58,994 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# Error en el adaptador de OpenAI (Llama-3.3-70B-Instruct): Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to Llama-3.3-70B-Instruct for Llama-3.3-70B-Instruct in East US 2 have exceeded the call rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-05-01-preview. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}
# 2025-11-02 20:12:58,996 - root - WARNING - ! Error de parseo (Usuario: U808C82QY, LLM: Llama-3.3-70B-Instruct, Ctx: False): No se encontró JSON.
# 2025-11-02 20:12:59,410 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 20:12:59,414 - root - WARNING - ! Error de parseo (Usuario: VPUPLRL9V, LLM: Llama-3.3-70B-Instruct, Ctx: False): JSON mal formado.
# 2025-11-02 20:12:59,554 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 20:12:59,556 - root - WARNING - ! Error de parseo (Usuario: U808C82QY, LLM: Llama-3.3-70B-Instruct, Ctx: True): JSON mal formado.
# 2025-11-02 20:12:59,569 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 20:12:59,571 - root - WARNING - ! Error de parseo (Usuario: UPY2VUC8P, LLM: Llama-3.3-70B-Instruct, Ctx: True): JSON mal formado.
# 2025-11-02 20:13:05,055 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 20:13:07,702 - root - ERROR - ! Error inesperado (Usuario: RCU80QGUY, LLM: Llama-3.3-70B-Instruct, Ctx: False): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=MP-Witch-DartGob-Cannon-MM-Fireball-IceSpirit
# 2025-11-02 20:13:07,708 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 20:13:07,711 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 20:13:07,713 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 20:13:09,609 - root - ERROR - ! Error inesperado (Usuario: 9P8RJLRR, LLM: Llama-3.3-70B-Instruct, Ctx: False): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=Hunter-Fireball-Ghost-Fisherman-ElectroSpirit-MM-IceGolem
# 2025-11-02 20:13:11,515 - root - ERROR - ! Error inesperado (Usuario: VPUPLRL9V, LLM: Llama-3.3-70B-Instruct, Ctx: True): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=BarbBarrel-Knight-Tesla-GobGang-Bowler-Log-IceSpirit
# 2025-11-02 20:13:13,333 - root - ERROR - ! Error inesperado (Usuario: UPY2VUC8P, LLM: Llama-3.3-70B-Instruct, Ctx: False): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=Log-Bowler-Fireball-eWiz-Barrel-MM-IceSpirit
# 2025-11-02 20:13:13,339 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 20:13:13,346 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 20:13:15,530 - root - INFO - Éxito: Usuario RUQYGQRJ2 (LLM: Llama-3.3-70B-Instruct, Ctx: True)
# 2025-11-02 20:13:18,601 - root - INFO - Éxito: Usuario 9P8RJLRR (LLM: Llama-3.3-70B-Instruct, Ctx: True)
# 2025-11-02 20:13:19,605 - root - INFO -
# --- Procesamiento de lotes completado. ---
# 2025-11-02 20:13:19,606 - root - INFO - Resultados válidos (parseados y guardados): 941 de 1500
# 2025-11-02 20:13:19,659 - root - INFO - Ejecución finalizada.
# 2025-11-02 20:13:19,660 - root - INFO - Resultados válidos guardados en: 'results/valid_results_20251102_182725.jsonl'
# 2025-11-02 20:13:19,661 - root - INFO - Resultados crudos guardados en: 'results/raw_results_20251102_182725.jsonl'

# %%
df = pd.read_json(output_filename, orient="records", lines=True)

# %%
df['correct_selection_count'] = df.apply(
    lambda row: sum(1 for item in row['deleted'] if item in row['seleccion']),
    axis=1
)
df.head()
# Out:
#                                           seleccion  \
# 0      [Goblin Gang, Inferno Dragon, Fireball, Zap]
# 1     [Goblin Giant, Firecracker, Goblin Gang, Zap]
# 2       [Fisherman, Fireball, Archers, Goblin Gang]
# 3      [Goblin Gang, Inferno Dragon, Fireball, Zap]
# 4  [Goblin Gang, Fireball, Ice Spirit, Mega Minion]
#
#                                              detalle  \
# 0  [{'carta': 'Goblin Gang', 'costo_elixir': '3',...
# 1  [{'carta': 'Goblin Giant', 'costo_elixir': '6'...
# 2  [{'carta': 'Fisherman', 'costo_elixir': '3', '...
# 3  [{'carta': 'Goblin Gang', 'costo_elixir': '3',...
# 4  [{'carta': 'Goblin Gang', 'costo_elixir': '3',...
#
#                                              resumen  n    user_id  \
# 0  Este mazo se enfoca en un estilo de juego de c...  4  VL0QCY9R8
# 1  Mazo de Beatdown con Goblin Giant como tanque ...  4  RLVLPLLRU
# 2  El mazo se enfoca en un estilo de juego de con...  4  UP80QCJJV
# 3  Este mazo se enfoca en un estilo de juego de c...  4  U9QUY9Y2Y
# 4  Este mazo se enfoca en un estilo de juego de c...  4  CVRURLY0U
#
#                                            deleted  \
# 0        [Zap, Mega Knight, Bandit, Spear Goblins]
# 1     [Arrows, Lumberjack, Graveyard, Dart Goblin]
# 2           [Tesla, Musketeer, P.E.K.K.A, The Log]
# 3   [Archer Queen, Valkyrie, Fire Spirit, The Log]
# 4  [Wizard, Mega Knight, Royal Giant, Goblin Cage]
#
#                                             original           llm  \
# 0    [Firecracker, Bats, Skeletons, Skeleton Barrel]  gpt-35-turbo
# 1              [Tesla, Mega Knight, Minions, Guards]  gpt-35-turbo
# 2  [Royal Delivery, Bowler, Mini P.E.K.K.A, Hog R...  gpt-35-turbo
# 3                   [Poison, Mortar, Goblins, Miner]  gpt-35-turbo
# 4  [Electro Wizard, Goblin Giant, Lumberjack, Eli...  gpt-35-turbo
#
#    with_context                               original_deck_rating  \
# 0         False  {'Attack': 3, 'Defense': 5, 'Synergy': 4, 'Ver...
# 1         False  {'Attack': 3, 'Defense': 5, 'Synergy': 2, 'Ver...
# 2         False  {'Attack': 3, 'Defense': 5, 'Synergy': 2, 'Ver...
# 3         False  {'Attack': 5, 'Defense': 5, 'Synergy': 5, 'Ver...
# 4         False  {'Attack': 5, 'Defense': 5, 'Synergy': 2, 'Ver...
#
#                                 selected_deck_rating  \
# 0  {'Attack': 2, 'Defense': 5, 'Synergy': 3, 'Ver...
# 1  {'Attack': 3, 'Defense': 5, 'Synergy': 3, 'Ver...
# 2  {'Attack': 3, 'Defense': 5, 'Synergy': 2, 'Ver...
# 3  {'Attack': 4, 'Defense': 5, 'Synergy': 5, 'Ver...
# 4  {'Attack': 3, 'Defense': 5, 'Synergy': 4, 'Ver...
#
#    total_original_deck_rating  total_selected_deck_rating  was_improved  \
# 0                          20                          20          True
# 1                          17                          19          True
# 2                          17                          17          True
# 3                          21                          22          True
# 4                          17                          19          True
#
#    correct_selection_count
# 0                        1
# 1                        0
# 2                        0
# 3                        0
# 4                        0

# %%
df['correct_selection_count'].groupby(df['llm']).value_counts()
# Out:
# llm                     correct_selection_count
# DeepSeek-V3.1           0                          147
#                         1                           81
#                         2                           20
#                         3                           10
#                         4                            3
# Llama-3.3-70B-Instruct  0                           19
#                         1                            9
#                         2                            3
# gpt-35-turbo            0                           52
#                         1                           13
#                         2                            2
# gpt-4o                  0                          162
#                         1                           78
#                         2                           26
#                         3                           13
#                         4                            5
# gpt-5-chat              0                          164
#                         1                           77
#                         2                           37
#                         3                           15
#                         4                            5
# Name: count, dtype: int64

# %%
res = (
    df.assign(wi=lambda d: d["was_improved"].astype(bool))
      .groupby("llm", as_index=False)
      .agg(total_mazos=("llm", "size"),
           mazos_mejorados=("wi", "sum"))
)
# Agregamos porcentaje de mazos mejorados
res['porcentaje_mejorados'] = (res['mazos_mejorados'] / res['total_mazos']) * 100
print(res)
# Out:
#                       llm  total_mazos  mazos_mejorados  porcentaje_mejorados
# 0           DeepSeek-V3.1          261              137             52.490421
# 1  Llama-3.3-70B-Instruct           31               15             48.387097
# 2            gpt-35-turbo           67               39             58.208955
# 3                  gpt-4o          284              126             44.366197
# 4              gpt-5-chat          298              177             59.395973

# %%
df_raw = pd.read_json(raw_filename, orient="records", lines=True)

# %%
# contamos cuantos validos e invalidos hay en raw_data para cada llm
df_raw['is_valid'] = df_raw['parsed_successfully'].astype(bool)
df_raw['llm'] = df_raw['llm'].astype('category')
df_raw['llm'].cat.categories
df_raw['is_valid'].groupby(df_raw['llm']).value_counts()
# Out:
# /var/folders/jv/rmw91d8n0g15ldpn_dkk73rh0000gn/T/ipykernel_91929/1222434325.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_raw['is_valid'].groupby(df_raw['llm']).value_counts()
# llm                     is_valid
# DeepSeek-V3.1           True        261
#                         False        39
# Llama-3.3-70B-Instruct  False       269
#                         True         31
# gpt-35-turbo            False       233
#                         True         67
# gpt-4o                  True        284
#                         False        16
# gpt-5-chat              True        298
#                         False         2
# Name: count, dtype: int64

# %%
hola_serie = df_raw['raw_response'][(df_raw['user_id'] == '999QV8RJU') & (df_raw['llm'] == 'Llama-3.3-70B-Instruct')]

if not hola_serie.empty:
    texto_completo = hola_serie.iloc[0]
    
    print(texto_completo)
else:
    print("No se encontró esa fila.")
# Out:
# ```json
# {
#   "seleccion": [
#     "Zap",
