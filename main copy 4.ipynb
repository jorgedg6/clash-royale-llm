# %%
import os
import asyncio
import aiohttp
import json
import re
from random import shuffle
import random
import pandas as pd
from dataclasses import dataclass

# %%
from card_utils import read_all_game_data, Card, PlayerCards, PlayerStats

# %%
random.seed(42)

# %%
from deck_rate_fetcher import fetch_deck_rating

# %%
import dotenv
dotenv.load_dotenv()

import nest_asyncio
nest_asyncio.apply()

# %%
from langchain_openai import AzureChatOpenAI
from openai import AsyncAzureOpenAI
from langchain_core.messages import SystemMessage, HumanMessage

# %%
game_cards_list, player_cards_list, player_stats, player_tags_list = read_all_game_data()

# %%
top_decks_per_card = pd.read_json("data/top_decks_per_card.json").to_dict()

# %%
print(top_decks_per_card)
# Out:
# {'Knight': {0: 'Graveyard,Knight,Ice Wizard,Witch,Goblin Hut,Vines,Poison,Barbarian Barrel', 1: 'Balloon,Miner,Little Prince,Knight,Bats,Goblin Cage,Rage,Arrows', 2: 'Mortar,Bandit,Knight,Archers,Ice Spirit,Inferno Tower,Rocket,Arrows', 3: 'Three Musketeers,Battle Ram,Royal Ghost,Bandit,Knight,Hunter,Elixir Collector,Barbarian Barrel', 4: 'Graveyard,Knight,Ice Golem,Bowler,Electro Wizard,Inferno Tower,Poison,The Log'}, 'Archers': {0: 'X Bow,Ice Golem,Archers,Skeletons,Fire Spirit,Tesla,Fireball,The Log', 1: 'Graveyard,Knight,Mega Minion,Archers,Skeletons,Tombstone,Poison,The Log', 2: 'Golem,Bandit,Night Witch,Baby Dragon,Archers,Skeletons,Lightning,The Log', 3: 'Mortar,Knight,Archers,Goblins,Ice Spirit,Rocket,Tornado,The Log', 4: 'Mortar,Knight,Princess,Archers,Skeletons,Ice Spirit,Poison,The Log'}, 'Goblins': {0: 'Giant,Electro Wizard,Night Witch,Mega Minion,Goblins,Tombstone,Poison,Zap', 1: 'Giant,Hog Rider,Musketeer,Minions,Goblins,Skeletons,Fireball,Zap', 2: 'Three Musketeers,Battle Ram,Bandit,Minion Horde,Goblins,Ice Spirit,Heal Spirit,Elixir Collector', 3: 'Ram Rider,Monk,Lumberjack,Magic Archer,Inferno Dragon,Goblins,Fireball,Barbarian Barrel', 4: 'Goblin Giant,Goblin Barrel,Dart Goblin,Goblin Gang,Goblins,Goblin Cage,Arrows,The Log'}, 'Giant': {0: 'Giant,Miner,Bandit,Night Witch,Minion Horde,Minions,Fireball,Zap', 1: 'Giant,Hog Rider,Musketeer,Barbarians,Minions,Elixir Collector,Fireball,Zap', 2: 'Giant,Miner,Musketeer,Minion Horde,Minions,Fireball,The Log,Zap', 3: 'Giant,Prince,Dark Prince,Magic Archer,Mega Minion,Ice Spirit,Poison,Zap', 4: 'Giant,Electro Wizard,Mega Minion,Minions,Skeletons,Elixir Collector,Fireball,Zap'}, 'P.E.K.K.A': {0: 'Miner,Pekka,Bandit,Hunter,Bats,Ice Spirit,Poison,Zap', 1: 'Battle Ram,Pekka,Magic Archer,Minions,Dart Goblin,Ice Spirit,Poison,Zap', 2: 'Battle Ram,Pekka,Bandit,Electro Wizard,Zappies,Flying Machine,Fireball,Zap', 3: 'Mega Knight,Pekka,Valkyrie,Wizard,Baby Dragon,Firecracker,Tornado,The Log', 4: 'Hog Rider,Pekka,Electro Wizard,Minions,Skeletons,Poison,The Log,Zap'}, 'Minions': {0: 'Golem,Night Witch,Baby Dragon,Minions,Skeletons,Tombstone,Lightning,The Log', 1: 'Battle Ram,Royal Recruits,Lumberjack,Inferno Dragon,Minions,Ice Spirit,Fireball,Zap', 2: 'Hog Rider,Pekka,Electro Wizard,Minions,Skeletons,Poison,The Log,Zap', 3: 'Giant,Balloon,Minion Horde,Minions,Skeleton Army,Skeletons,Freeze,Arrows', 4: 'Hog Rider,Royal Ghost,Ice Golem,Inferno Dragon,Minions,Guards,Poison,Zap'}, 'Balloon': {0: 'Balloon,Miner,Ice Golem,Musketeer,Skeletons,Bomb Tower,Vines,Barbarian Barrel', 1: 'Balloon,Miner,Rascals,Ice Golem,Bats,Inferno Tower,Barbarian Barrel,Giant Snowball', 2: 'Balloon,Lumberjack,Bowler,Inferno Dragon,Electro Dragon,Freeze,Tornado,Barbarian Barrel', 3: 'Lava Hound,Balloon,Mini Pekka,Mega Minion,Minions,Fireball,Royal Delivery,Zap', 4: 'Balloon,Ice Golem,Musketeer,Minions,Skeleton Army,Tombstone,Fireball,Zap'}, 'Witch': {0: 'Golem,Bandit,Witch,Night Witch,Inferno Dragon,Fire Spirit,Poison,Tornado', 1: 'Graveyard,Valkyrie,Witch,Zappies,Goblin Hut,Freeze,Mirror,Barbarian Barrel', 2: 'Skeleton Barrel,Giant Skeleton,Witch,Bats,Firecracker,Electro Spirit,Bomb Tower,Tornado', 3: 'Elite Barbarians,Witch,Night Witch,Skeleton Army,Goblins,Rage,Poison,Zap', 4: 'Goblin Drill,Wall Breakers,Skeleton Barrel,Valkyrie,Witch,Mega Minion,Skeletons,Barbarian Barrel'}, 'Barbarians': {0: 'Hog Rider,Goblin Barrel,Barbarians,Minion Horde,Goblins,Spear Goblins,Arrows,Zap', 1: 'Hog Rider,Mini Pekka,Musketeer,Barbarians,Inferno Dragon,Arrows,Giant Snowball,Zap', 2: 'Lava Hound,Miner,Spirit Empress,Barbarians,Flying Machine,Tombstone,Goblin Curse,Zap', 3: 'Golem,Lumberjack,Barbarians,Electro Dragon,Skeleton Dragons,Elixir Collector,Tornado,Barbarian Barrel', 4: 'Goblin Giant,Goblin Demolisher,Barbarians,Dart Goblin,Goblin Gang,Goblin Cage,Arrows,The Log'}, 'Golem': {0: 'Golem,Elite Barbarians,Lumberjack,Night Witch,Mega Minion,Bomber,Arrows,Zap', 1: 'Golem,Lumberjack,Night Witch,Guards,Ice Spirit,Elixir Colle ...

# %%
for card_name in top_decks_per_card:
    for key in top_decks_per_card[card_name].keys():
        deck_list = top_decks_per_card[card_name][key].split(',')
        shuffle(deck_list)
        top_decks_per_card[card_name][key] = deck_list

# %%
print(top_decks_per_card)
# Out:
# {'Knight': {0: ['Witch', 'Goblin Hut', 'Poison', 'Barbarian Barrel', 'Ice Wizard', 'Vines', 'Graveyard', 'Knight'], 1: ['Knight', 'Arrows', 'Little Prince', 'Balloon', 'Bats', 'Rage', 'Goblin Cage', 'Miner'], 2: ['Archers', 'Inferno Tower', 'Knight', 'Ice Spirit', 'Bandit', 'Rocket', 'Arrows', 'Mortar'], 3: ['Royal Ghost', 'Battle Ram', 'Three Musketeers', 'Barbarian Barrel', 'Knight', 'Elixir Collector', 'Hunter', 'Bandit'], 4: ['Inferno Tower', 'Ice Golem', 'The Log', 'Bowler', 'Knight', 'Graveyard', 'Poison', 'Electro Wizard']}, 'Archers': {0: ['Tesla', 'Skeletons', 'Fireball', 'Fire Spirit', 'X Bow', 'The Log', 'Ice Golem', 'Archers'], 1: ['Archers', 'Knight', 'Graveyard', 'The Log', 'Skeletons', 'Mega Minion', 'Poison', 'Tombstone'], 2: ['Skeletons', 'The Log', 'Lightning', 'Night Witch', 'Archers', 'Golem', 'Baby Dragon', 'Bandit'], 3: ['Archers', 'Ice Spirit', 'The Log', 'Knight', 'Tornado', 'Mortar', 'Rocket', 'Goblins'], 4: ['Ice Spirit', 'Skeletons', 'Knight', 'Princess', 'The Log', 'Mortar', 'Poison', 'Archers']}, 'Goblins': {0: ['Goblins', 'Giant', 'Mega Minion', 'Tombstone', 'Electro Wizard', 'Poison', 'Zap', 'Night Witch'], 1: ['Giant', 'Zap', 'Minions', 'Fireball', 'Hog Rider', 'Skeletons', 'Goblins', 'Musketeer'], 2: ['Three Musketeers', 'Minion Horde', 'Bandit', 'Battle Ram', 'Elixir Collector', 'Heal Spirit', 'Ice Spirit', 'Goblins'], 3: ['Inferno Dragon', 'Goblins', 'Fireball', 'Magic Archer', 'Lumberjack', 'Barbarian Barrel', 'Monk', 'Ram Rider'], 4: ['Goblin Giant', 'The Log', 'Arrows', 'Goblin Barrel', 'Dart Goblin', 'Goblin Cage', 'Goblins', 'Goblin Gang']}, 'Giant': {0: ['Minion Horde', 'Zap', 'Giant', 'Bandit', 'Miner', 'Night Witch', 'Minions', 'Fireball'], 1: ['Musketeer', 'Giant', 'Hog Rider', 'Fireball', 'Barbarians', 'Zap', 'Elixir Collector', 'Minions'], 2: ['Miner', 'Zap', 'Fireball', 'The Log', 'Giant', 'Minion Horde', 'Minions', 'Musketeer'], 3: ['Mega Minion', 'Zap', 'Prince', 'Giant', 'Magic Archer', 'Ice Spirit', 'Poison', 'Dark Prince'], 4: ['Electro Wizard', 'Minions', 'Elixir Collector', 'Giant', 'Fireball', 'Mega Minion', 'Skeletons', 'Zap']}, 'P.E.K.K.A': {0: ['Hunter', 'Zap', 'Pekka', 'Miner', 'Bandit', 'Ice Spirit', 'Poison', 'Bats'], 1: ['Poison', 'Ice Spirit', 'Dart Goblin', 'Pekka', 'Zap', 'Battle Ram', 'Minions', 'Magic Archer'], 2: ['Bandit', 'Electro Wizard', 'Battle Ram', 'Pekka', 'Zap', 'Flying Machine', 'Fireball', 'Zappies'], 3: ['Wizard', 'Firecracker', 'Pekka', 'The Log', 'Mega Knight', 'Tornado', 'Baby Dragon', 'Valkyrie'], 4: ['Skeletons', 'Poison', 'Minions', 'Hog Rider', 'Zap', 'The Log', 'Electro Wizard', 'Pekka']}, 'Minions': {0: ['Baby Dragon', 'Lightning', 'Skeletons', 'The Log', 'Golem', 'Minions', 'Tombstone', 'Night Witch'], 1: ['Royal Recruits', 'Fireball', 'Battle Ram', 'Inferno Dragon', 'Ice Spirit', 'Minions', 'Zap', 'Lumberjack'], 2: ['Hog Rider', 'Pekka', 'Zap', 'The Log', 'Electro Wizard', 'Poison', 'Minions', 'Skeletons'], 3: ['Skeletons', 'Minions', 'Skeleton Army', 'Minion Horde', 'Giant', 'Freeze', 'Arrows', 'Balloon'], 4: ['Zap', 'Ice Golem', 'Minions', 'Royal Ghost', 'Guards', 'Poison', 'Hog Rider', 'Inferno Dragon']}, 'Balloon': {0: ['Vines', 'Barbarian Barrel', 'Musketeer', 'Ice Golem', 'Miner', 'Skeletons', 'Balloon', 'Bomb Tower'], 1: ['Rascals', 'Inferno Tower', 'Balloon', 'Giant Snowball', 'Barbarian Barrel', 'Miner', 'Bats', 'Ice Golem'], 2: ['Electro Dragon', 'Bowler', 'Barbarian Barrel', 'Inferno Dragon', 'Freeze', 'Balloon', 'Lumberjack', 'Tornado'], 3: ['Mini Pekka', 'Balloon', 'Zap', 'Minions', 'Lava Hound', 'Fireball', 'Mega Minion', 'Royal Delivery'], 4: ['Musketeer', 'Minions', 'Zap', 'Skeleton Army', 'Ice Golem', 'Balloon', 'Fireball', 'Tombstone']}, 'Witch': {0: ['Fire Spirit', 'Inferno Dragon', 'Golem', 'Poison', 'Tornado', 'Bandit', 'Night Witch', 'Witch'], 1: ['Valkyrie', 'Zappies', 'Witch', 'Freeze', 'Graveyard', 'Goblin Hut', 'Mirror', 'Barbarian Barrel'], 2: ['Skeleton Barrel', 'Witch', 'Firecracker', 'Bats', 'Electro Spirit' ...

# %%
@dataclass
class LLMModel:
    name: str
    instance: AzureChatOpenAI | AsyncAzureOpenAI

# %%
llm_gpt3 = LLMModel(
    name="gpt-35-turbo",
    instance=AzureChatOpenAI(
        model_name="gpt-35-turbo",
        temperature=0,
        max_tokens=None,
        timeout=None,
        max_retries=2,
    )
)

llm_gpt4o = LLMModel(
    name="gpt-4o",
    instance=AzureChatOpenAI(
        model_name="gpt-4o",
        temperature=0,
        max_tokens=None,
        timeout=None,
        max_retries=2,
    )
)

llm_gpt5 = LLMModel(
    name="gpt-5-chat",
    instance=AzureChatOpenAI(
        model_name="gpt-5-chat",
        temperature=0,
        max_tokens=None,
        timeout=None,
        max_retries=2,
    )
)

# %%
class SimpleAIMessage:
    """Clase simple para empaquetar la respuesta con un atributo .content"""
    def __init__(self, content):
        self.content = content

# Adaptador para AsyncAzureOpenAI de openai
class OpenAIClientAdapter:
    def __init__(self, client: AsyncAzureOpenAI, model_name: str, temperature: float = 0):
        self.client = client
        self.model_name = model_name
        self.temperature = temperature
        self.
        print(f"Adaptador creado para el modelo: {self.model_name}")

    def _convert_lc_messages_to_dict(self, messages):
        output_messages = []
        for msg in messages:
            role = msg.type
            if role == "human":
                role = "user"
            
            output_messages.append({"role": role, "content": msg.content})
        return output_messages

    async def ainvoke(self, messages):
        try:
            dict_messages = self._convert_lc_messages_to_dict(messages)
            
            response = await self.client.chat.completions.create(
                model=self.model_name,
                messages=dict_messages,
                temperature=self.temperature
            )
            
            content = response.choices[0].message.content
            
            return SimpleAIMessage(content=content)
        
        except Exception as e:
            print(f"Error en el adaptador de OpenAI ({self.model_name}): {e}")
            return SimpleAIMessage(content=None)

# %%
print("Creando clientes y adaptadores...")

async_openai_client = AsyncAzureOpenAI(
    azure_endpoint=dotenv.get_key(dotenv.find_dotenv(), "AZURE_OPENAI_ENDPOINT"),
    api_key=dotenv.get_key(dotenv.find_dotenv(), "AZURE_OPENAI_API_KEY"),
    api_version="2024-05-01-preview"
)

llm_grok_adapter = LLMModel(
    name="grok-4-fast-non-reasoning",
    instance=OpenAIClientAdapter(
        client=async_openai_client,
        model_name="grok-4-fast-non-reasoning",
        temperature=0
    )
)

llm_deepseek_adapter = LLMModel(
    name="DeepSeek-V3.1",
    instance=OpenAIClientAdapter(
        client=async_openai_client,
        model_name="DeepSeek-V3.1",
        temperature=0
    )
)

llm_llama_adapter = LLMModel(
    name="Llama-3.3-70B-Instruct",
    instance=OpenAIClientAdapter(
        client=async_openai_client,
        model_name="Llama-3.3-70B-Instruct",
        temperature=0
    )
)
# Out:
# Creando clientes y adaptadores...
# Adaptador creado para el modelo: grok-4-fast-non-reasoning
# Adaptador creado para el modelo: DeepSeek-V3.1
# Adaptador creado para el modelo: Llama-3.3-70B-Instruct

# %% [markdown]
# ### Test

# %%
import logging
import time
import sys

LOG_LEVEL = logging.INFO 

logging.basicConfig(
    level=LOG_LEVEL,
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler("logs/app_run{}.log".format(time.strftime('%Y%m%d_%H%M%S'))), 
        logging.StreamHandler(sys.stdout) 
    ],
    force=True 
)

logging.info("Logger configurado exitosamente.")
# Out:
# 2025-11-02 23:25:19,065 - root - INFO - Logger configurado exitosamente.

# %%
with open("prompts/human_prompt_no_context.txt", "r", encoding="utf-8") as f:
    human_prompt_no_context = f.read().replace("{", "{{").replace("}", "}}")
    human_prompt_no_context = human_prompt_no_context.replace("\n", " ").replace('"', '\\"')
    human_prompt_no_context = human_prompt_no_context.replace("$", "{").replace("%", "}")

with open("prompts/human_prompt_context.txt", "r", encoding="utf-8") as f:
    human_prompt_context = f.read().replace("{", "{{").replace("}", "}}")
    human_prompt_context = human_prompt_context.replace("\n", " ").replace('"', '\\"')
    human_prompt_context = human_prompt_context.replace("$", "{").replace("%", "}")

with open("prompts/system_prompt.txt", "r", encoding="utf-8") as f:
    system_prompt = f.read()

# %%
with open("prompts/human_prompt_no_context_lite.txt", "r", encoding="utf-8") as f:
    human_prompt_no_context_lite = f.read().replace("{", "{{").replace("}", "}}")
    human_prompt_no_context_lite = human_prompt_no_context_lite.replace("\n", " ").replace('"', '\\"')
    human_prompt_no_context_lite = human_prompt_no_context_lite.replace("$", "{").replace("%", "}")

with open("prompts/human_prompt_context_lite.txt", "r", encoding="utf-8") as f:
    human_prompt_context_lite = f.read().replace("{", "{{").replace("}", "}}")
    human_prompt_context_lite = human_prompt_context_lite.replace("\n", " ").replace('"', '\\"')
    human_prompt_context_lite = human_prompt_context_lite.replace("$", "{").replace("%", "}")

# %%
with open("prompts/human_prompt_no_context_semi_lite.txt", "r", encoding="utf-8") as f:
    human_prompt_no_context_semi_lite = f.read().replace("{", "{{").replace("}", "}}")
    human_prompt_no_context_semi_lite = human_prompt_no_context_semi_lite.replace("\n", " ").replace('"', '\\"')
    human_prompt_no_context_semi_lite = human_prompt_no_context_semi_lite.replace("$", "{").replace("%", "}")

with open("prompts/human_prompt_context_semi_lite.txt", "r", encoding="utf-8") as f:
    human_prompt_context_semi_lite = f.read().replace("{", "{{").replace("}", "}}")
    human_prompt_context_semi_lite = human_prompt_context_semi_lite.replace("\n", " ").replace('"', '\\"')
    human_prompt_context_semi_lite = human_prompt_context_semi_lite.replace("$", "{").replace("%", "}")

# %%
score_mapping = {
    "RIP": 0,
    "Bad": 1,
    "Mediocre": 2,
    "Good": 3,
    "Great!": 4,
    "Godly!": 5,
}

# %%
def process_deck_rating(rating: str) -> dict:
    rating = rating.strip()
    rating = rating.split(" ")
    ratings = {
        "Attack": score_mapping.get(rating[1], -1),
        "Defense": score_mapping.get(rating[3], -1),
        "Synergy": score_mapping.get(rating[5], -1),
        "Versatility": score_mapping.get(rating[7], -1),
        "F2P score": score_mapping.get(rating[10], -1),
    }
    return ratings

# %%
import re
import json

def parse_json_safe(player_cards, llm_response, llm_name, with_context: bool):
    player_tag = player_cards.tag[1:]
    deck_cards = player_cards.deck_cards
    deleted_cards = player_cards.deleted_cards or []

    try:
        s = (llm_response or "").strip()

        m = re.search(r"```(?:json)?\\s*([\\s\\S]*?)\\s*```", s, flags=re.IGNORECASE)
        if m:
            candidate = m.group(1).strip()
        else:
            candidate = s

        first_brace = candidate.find("{")
        first_bracket = candidate.find("[")
        starts = [i for i in (first_brace, first_bracket) if i != -1]
        
        if not starts:
            error_msg = f"! Error de parseo (Usuario: {player_tag}, LLM: {llm_name}, Ctx: {with_context}): No se encontró JSON."
            logging.warning(error_msg)
            return None, error_msg

        start = min(starts)
        end = max(candidate.rfind("}"), candidate.rfind("]"))
        
        if end == -1 or end < start:
            error_msg = f"! Error de parseo (Usuario: {player_tag}, LLM: {llm_name}, Ctx: {with_context}): JSON mal formado."
            logging.warning(error_msg)
            return None, error_msg
            
        candidate = candidate[start:end+1]
        parsed = json.loads(candidate)

        if isinstance(parsed, dict):
            parsed["user_id"] = player_tag
            parsed["deleted"] = list(map(lambda c: c.name, deleted_cards))
            parsed["original"] = list(map(lambda c: c.name, deck_cards))
            parsed["llm"] = llm_name
            parsed["with_context"] = with_context
        else:
            parsed = {
                "user_id": player_tag,
                "data": parsed,
                "deleted": list(map(lambda c: c.name, deleted_cards)),
                "llm": llm_name,
                "with_context": with_context
            }

        original_deck_rating_string = fetch_deck_rating(parsed["original"] + parsed["deleted"])
        selected_deck_rating_string = fetch_deck_rating(parsed["original"] + parsed["seleccion"])

        original_deck_ratings = process_deck_rating(original_deck_rating_string)
        selected_deck_ratings = process_deck_rating(selected_deck_rating_string)

        parsed["original_deck_rating"] = original_deck_ratings
        parsed["selected_deck_rating"] = selected_deck_ratings

        total_original_deck_rating = sum(original_deck_ratings.values())
        total_selected_deck_rating = sum(selected_deck_ratings.values())

        parsed["total_original_deck_rating"] = total_original_deck_rating
        parsed["total_selected_deck_rating"] = total_selected_deck_rating

        parsed["was_improved"] = total_selected_deck_rating >= total_original_deck_rating

        return parsed, None

    except json.JSONDecodeError as e:
        error_msg = f"X Error JSONDecode (Usuario: {player_tag}, LLM: {llm_name}, Ctx: {with_context}): {e}"
        logging.error(error_msg)
        return None, error_msg
    except Exception as e:
        error_msg = f"! Error inesperado (Usuario: {player_tag}, LLM: {llm_name}, Ctx: {with_context}): {e}"
        logging.error(error_msg)
        return None, error_msg

# %%
def write_prompt_file(string, user_id):
    with open(f"final_prompts_lite/user_{user_id}.txt", "w", encoding="utf-8") as f:
        f.write(string)

# %%
async def process_user_recommendation(
    llm, 
    player_cards, 
    system_prompt_str, 
    human_prompt_context_str,
    human_prompt_no_context_str,
    with_context: bool,
    valid_f,
    raw_f,
    file_lock
):
    player_tag = player_cards.tag[1:]
    available_cards = player_cards.available_cards
    deck_cards = player_cards.deck_cards

    available_cards_json = json.dumps(list(map(lambda c: c.name, available_cards)))
    deck_cards_json = json.dumps(list(map(lambda c: c.name, deck_cards)))

    try:
        if with_context:
            string_top_decks = "<Top 5 Decks para usar con cada una de las CARTAS_DISPONIBLES>\\n"
            
            for card in deck_cards:
                card_name = card.name
                string_top_decks += f'  <CardGroup name="{card_name}">\\n'
                decks_for_card = top_decks_per_card.get(card_name, {}) 
                for deck_key in decks_for_card.keys():
                    deck_list = decks_for_card[deck_key]
                    string_top_decks += "    <Deck>\\n"
                    for individual_card_name in deck_list:
                        string_top_decks += f'      <Card>{individual_card_name.strip()}</Card>\\n'
                    string_top_decks += "    </Deck>\\n"
                string_top_decks += f'  </CardGroup>\\n'
            string_top_decks += "</TopDecks>"

            rendered_human_prompt = human_prompt_context_str.format(
                TOP_DECKS=string_top_decks,
                CARTAS_DISPONIBLES=available_cards_json,
                CARTAS_SELECCIONADAS=deck_cards_json
            )
        else:
            rendered_human_prompt = human_prompt_no_context_str.format(
                CARTAS_DISPONIBLES=available_cards_json,
                CARTAS_SELECCIONADAS=deck_cards_json
            )
        
        prompt_filename_tag = f"{player_tag}{'_ctx' if with_context else '_noctx'}"
        write_prompt_file(rendered_human_prompt, prompt_filename_tag)

    except Exception as e:
        logging.error(f"! Error al renderizar prompt para usuario {player_tag} (Ctx: {with_context}): {e}")
        return False

    messages = [
        SystemMessage(content=system_prompt_str),
        HumanMessage(content=rendered_human_prompt),
    ]

    try:
        ai_msg = await llm.instance.ainvoke(messages)
        response_content = ai_msg.content

        parsed_result, parse_error = parse_json_safe(player_cards, response_content, llm.name, with_context)
        
        raw_log_data = {
            "user_id": player_tag,
            "llm": llm.name,
            "with_context": with_context,
            "raw_response": response_content,
            "parsed_successfully": (parsed_result is not None),
            "parse_error": parse_error
        }

        async with file_lock:
            raw_f.write(json.dumps(raw_log_data, ensure_ascii=False) + '\n')
            raw_f.flush()
            
            if parsed_result:
                valid_f.write(json.dumps(parsed_result, ensure_ascii=False) + '\n')
                valid_f.flush()

        if parsed_result:
            logging.info(f"Éxito: Usuario {player_tag} (LLM: {llm.name}, Ctx: {with_context})")
            return True
        else:
            return False

    except Exception as e:
        logging.error(f"! Error API (Usuario: {player_tag}, LLM: {llm.name}, Ctx: {with_context}): {e}")
        raw_log_data = {
            "user_id": player_tag,
            "llm": llm.name,
            "with_context": with_context,
            "raw_response": None,
            "parsed_successfully": False,
            "parse_error": f"API Error: {e}"
        }
        async with file_lock:
            raw_f.write(json.dumps(raw_log_data, ensure_ascii=False) + '\n')
            raw_f.flush()
            
        return False

# %%
def generate_human_prompt(human_prompt_template, top_decks, available_cards, selected_cards):
    rendered_human_prompt = human_prompt_template.format(
        TOP_DECKS=top_decks,
        CARTAS_DISPONIBLES=available_cards,
        CARTAS_SELECCIONADAS=selected_cards
    )
    return rendered_human_prompt

# %%
def shuffle_and_remove_cards(player_cards_list, num_to_remove=4):
    updated_player_cards_list = []
    for player_cards in player_cards_list:
        
        available_copy = list(player_cards.available_cards)
        selected_copy = list(player_cards.deck_cards)

        shuffle(available_copy)
        shuffle(selected_copy)

        to_delete = selected_copy[-num_to_remove:]
        selected_for_prompt = selected_copy[:-num_to_remove]

        updated_player_cards = PlayerCards(
            tag=player_cards.tag,
            available_cards=available_copy,
            deck_cards=selected_for_prompt,
            deleted_cards=to_delete
        )
        updated_player_cards_list.append(updated_player_cards)
    
    return updated_player_cards_list

# %%
import time

async def run_all_models_async(
    player_cards_list, 
    models_list,
    system_prompt_str, 
    human_prompt_context_str,
    human_prompt_no_context_str,
    batch_size=50, 
    num_batches=None,
    starting_card_number=4
):
    """
    Orquesta la ejecución asíncrona para todos los LLMs y usuarios,
    controlando el tamaño de los lotes y guardando los resultados en JSONL.
    """
    selected_player_cards_list = shuffle_and_remove_cards(
        player_cards_list, 
        num_to_remove= 8 - starting_card_number
    )

    if num_batches is not None:
        total_to_process = batch_size * num_batches
        players_to_process = selected_player_cards_list[:total_to_process]
    else:
        players_to_process = selected_player_cards_list

    logging.info(f"Iniciando procesamiento para {len(players_to_process)} jugadores a través de {len(models_list)} LLMs (x2 con/sin contexto).")

    output_timestamp = time.strftime('%Y%m%d_%H%M%S')
    valid_results_filename = f"results/valid_results_{output_timestamp}.jsonl"
    raw_results_filename = f"results/raw_results_{output_timestamp}.jsonl"
    
    file_lock = asyncio.Lock()
    
    with open(valid_results_filename, 'a', encoding='utf-8') as valid_f, \
         open(raw_results_filename, 'a', encoding='utf-8') as raw_f:

        all_tasks = []
        for llm in models_list:
            logging.info(f"Creando tareas para: {llm.name}...")
            for player_cards in players_to_process:
                for with_context_flag in [True, False]:
                    task = process_user_recommendation(
                        llm,
                        player_cards, 
                        system_prompt_str, 
                        human_prompt_context_str,
                        human_prompt_no_context_str,
                        with_context_flag,
                        valid_f,
                        raw_f,
                        file_lock
                    )
                    all_tasks.append(task)
                
        logging.info(f"Total de tareas creadas: {len(all_tasks)}")
        
        all_results = []
        total_batches = (len(all_tasks) + batch_size - 1) // batch_size
        
        for i in range(0, len(all_tasks), batch_size):
            current_batch_num = (i // batch_size) + 1
            batch_tasks = all_tasks[i:i + batch_size]
            logging.info(f"\n--- Ejecutando Lote {current_batch_num} / {total_batches} (Tamaño: {len(batch_tasks)}) ---")
            
            batch_results = await asyncio.gather(*batch_tasks, return_exceptions=True)
            all_results.extend(batch_results)
            
            for idx, result in enumerate(batch_results):
                if isinstance(result, Exception):
                    logging.error(f"! Excepción en tarea del lote {current_batch_num}: {result}")
            
            await asyncio.sleep(1) 

    logging.info("\n--- Procesamiento de lotes completado. ---")
    
    valid_count = sum(1 for r in all_results if r is True)
    logging.info(f"Resultados válidos (parseados y guardados): {valid_count} de {len(all_tasks)}")

    return valid_results_filename, raw_results_filename

# %%
import time

models_to_run = [
    #llm_gpt3,
    #llm_gpt4o,
    #llm_gpt5,
    #llm_grok_adapter,
    llm_deepseek_adapter,
    llm_llama_adapter,
]

BATCH_SIZE = 10
NUM_BATCHES = 1

logging.info("Iniciando la ejecución asíncrona...")

valid_filename, raw_filename = await run_all_models_async(
    player_cards_list=player_cards_list,
    models_list=models_to_run,
    system_prompt_str=system_prompt,
    human_prompt_context_str=human_prompt_context_semi_lite,
    human_prompt_no_context_str=human_prompt_no_context_semi_lite,
    batch_size=BATCH_SIZE,
    num_batches=NUM_BATCHES
)

logging.info(f"Ejecución finalizada.")
logging.info(f"Resultados válidos guardados en: '{valid_filename}'")
logging.info(f"Resultados crudos guardados en: '{raw_filename}'")

output_filename = valid_filename
# Out:
# 2025-11-02 23:25:19,112 - root - INFO - Iniciando la ejecución asíncrona...
# 2025-11-02 23:25:20,122 - root - INFO - Iniciando procesamiento para 10 jugadores a través de 2 LLMs (x2 con/sin contexto).
# 2025-11-02 23:25:20,123 - root - INFO - Creando tareas para: DeepSeek-V3.1...
# 2025-11-02 23:25:20,123 - root - INFO - Creando tareas para: Llama-3.3-70B-Instruct...
# 2025-11-02 23:25:20,124 - root - INFO - Total de tareas creadas: 40
# 2025-11-02 23:25:20,124 - root - INFO -
# --- Ejecutando Lote 1 / 4 (Tamaño: 10) ---
# 2025-11-02 23:25:21,419 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/DeepSeek-V3.1/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 23:25:22,589 - root - INFO - Éxito: Usuario 2G22QVP89 (LLM: DeepSeek-V3.1, Ctx: False)
# 2025-11-02 23:25:22,591 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/DeepSeek-V3.1/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 23:25:22,591 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/DeepSeek-V3.1/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 23:25:22,592 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/DeepSeek-V3.1/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 23:25:22,593 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/DeepSeek-V3.1/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 23:25:22,593 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/DeepSeek-V3.1/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 23:25:22,594 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/DeepSeek-V3.1/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 23:25:22,595 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/DeepSeek-V3.1/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 23:25:22,595 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/DeepSeek-V3.1/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 23:25:22,596 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/DeepSeek-V3.1/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 23:25:23,711 - root - INFO - Éxito: Usuario LU2QQJU0Y (LLM: DeepSeek-V3.1, Ctx: False)
# 2025-11-02 23:25:24,947 - root - INFO - Éxito: Usuario 999QV8RJU (LLM: DeepSeek-V3.1, Ctx: False)
# 2025-11-02 23:25:26,123 - root - INFO - Éxito: Usuario VL0QCY9R8 (LLM: DeepSeek-V3.1, Ctx: True)
# 2025-11-02 23:25:27,664 - root - INFO - Éxito: Usuario L0092LLGP (LLM: DeepSeek-V3.1, Ctx: True)
# 2025-11-02 23:25:28,407 - root - INFO - Éxito: Usuario L0092LLGP (LLM: DeepSeek-V3.1, Ctx: False)
# 2025-11-02 23:25:30,890 - root - INFO - Éxito: Usuario VL0QCY9R8 (LLM: DeepSeek-V3.1, Ctx: False)
# 2025-11-02 23:25:34,165 - root - INFO - Éxito: Usuario 2G22QVP89 (LLM: DeepSeek-V3.1, Ctx: True)
# 2025-11-02 23:25:35,040 - root - INFO - Éxito: Usuario 999QV8RJU (LLM: DeepSeek-V3.1, Ctx: True)
# 2025-11-02 23:25:39,199 - root - INFO - Éxito: Usuario LU2QQJU0Y (LLM: DeepSeek-V3.1, Ctx: True)
# 2025-11-02 23:25:40,201 - root - INFO -
# --- Ejecutando Lote 2 / 4 (Tamaño: 10) ---
# 2025-11-02 23:25:41,635 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/DeepSeek-V3.1/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# 2025-11-02 23:25:41,640 - openai._base_client - INFO - Retrying request to /chat/completions in 0.416985 seconds
# 2025-11-02 23:25:41,641 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/DeepSeek-V3.1/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# 2025-11-02 23:25:41,642 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/DeepSeek-V3.1/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# 2025-11-02 23:25:41,644 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/DeepSeek-V3.1/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# 2025-11-02 23:25:41,645 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/DeepSeek-V3.1/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# 2025-11-02 23:25:41,646 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/DeepSeek-V3.1/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# 2025-11-02 23:25:41,647 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/DeepSeek-V3.1/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# 2025-11-02 23:25:41,647 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/DeepSeek-V3.1/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# 2025-11-02 23:25:41,648 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/DeepSeek-V3.1/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# 2025-11-02 23:25:41,649 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/DeepSeek-V3.1/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# 2025-11-02 23:25:41,650 - openai._base_client - INFO - Retrying request to /chat/completions in 0.474005 seconds
# 2025-11-02 23:25:41,651 - openai._base_client - INFO - Retrying request to /chat/completions in 0.491076 seconds
# 2025-11-02 23:25:41,652 - openai._base_client - INFO - Retrying request to /chat/completions in 0.460715 seconds
# 2025-11-02 23:25:41,654 - openai._base_client - INFO - Retrying request to /chat/completions in 0.443355 seconds
# 2025-11-02 23:25:41,655 - openai._base_client - INFO - Retrying request to /chat/completions in 0.408661 seconds
# 2025-11-02 23:25:41,656 - openai._base_client - INFO - Retrying request to /chat/completions in 0.405745 seconds
# 2025-11-02 23:25:41,657 - openai._base_client - INFO - Retrying request to /chat/completions in 0.423173 seconds
# 2025-11-02 23:25:41,658 - openai._base_client - INFO - Retrying request to /chat/completions in 0.435109 seconds
# 2025-11-02 23:25:41,659 - openai._base_client - INFO - Retrying request to /chat/completions in 0.437707 seconds
# 2025-11-02 23:25:42,289 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/DeepSeek-V3.1/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# 2025-11-02 23:25:42,292 - openai._base_client - INFO - Retrying request to /chat/completions in 0.913703 seconds
# 2025-11-02 23:25:42,293 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/DeepSeek-V3.1/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# 2025-11-02 23:25:42,295 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/DeepSeek-V3.1/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# 2025-11-02 23:25:42,296 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/DeepSeek-V3.1/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# 2025-11-02 23:25:42,298 - openai._base_client - INFO - Retrying request to /chat/completions in 0.993780 seconds
# 2025-11-02 23:25:42,299 - openai._base_client - INFO - Retrying request to /chat/completions in 0.780148 seconds
# 2025-11-02 23:25:42,300 - openai._base_client - INFO - Retrying request to /chat/completions in 0.770253 seconds
# 2025-11-02 23:25:42,302 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/DeepSeek-V3.1/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# 2025-11-02 23:25:42,303 - openai._base_client - INFO - Retrying request to /chat/completions in 0.929265 seconds
# 2025-11-02 23:25:42,304 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/DeepSeek-V3.1/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# 2025-11-02 23:25:42,307 - openai._base_client - INFO - Retrying request to /chat/completions in 0.894393 seconds
# 2025-11-02 23:25:42,310 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/DeepSeek-V3.1/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# 2025-11-02 23:25:42,311 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/DeepSeek-V3.1/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# 2025-11-02 23:25:42,312 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/DeepSeek-V3.1/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# 2025-11-02 23:25:42,313 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/DeepSeek-V3.1/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# 2025-11-02 23:25:42,315 - openai._base_client - INFO - Retrying request to /chat/completions in 0.831578 seconds
# 2025-11-02 23:25:42,316 - openai._base_client - INFO - Retrying request to /chat/completions in 0.815980 seconds
# 2025-11-02 23:25:42,317 - openai._base_client - INFO - Retrying request to /chat/completions in 0.958286 seconds
# 2025-11-02 23:25:42,318 - openai._base_client - INFO - Retrying request to /chat/completions in 0.999264 seconds
# 2025-11-02 23:25:43,234 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/DeepSeek-V3.1/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# 2025-11-02 23:25:43,236 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/DeepSeek-V3.1/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# Error en el adaptador de OpenAI (DeepSeek-V3.1): Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to DeepSeek-V3.1 for DeepSeek-V3.1 in East US 2 have exceeded the call rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-05-01-preview. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}
# 2025-11-02 23:25:43,239 - root - WARNING - ! Error de parseo (Usuario: 9JL9080GL, LLM: DeepSeek-V3.1, Ctx: True): No se encontró JSON.
# Error en el adaptador de OpenAI (DeepSeek-V3.1): Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to DeepSeek-V3.1 for DeepSeek-V3.1 in East US 2 have exceeded the call rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-05-01-preview. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}
# 2025-11-02 23:25:43,243 - root - WARNING - ! Error de parseo (Usuario: UL98CLGP, LLM: DeepSeek-V3.1, Ctx: True): No se encontró JSON.
# 2025-11-02 23:25:43,286 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/DeepSeek-V3.1/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# Error en el adaptador de OpenAI (DeepSeek-V3.1): Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to DeepSeek-V3.1 for DeepSeek-V3.1 in East US 2 have exceeded the call rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-05-01-preview. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}
# 2025-11-02 23:25:43,288 - root - WARNING - ! Error de parseo (Usuario: YC9RRVYYL, LLM: DeepSeek-V3.1, Ctx: True): No se encontró JSON.
# 2025-11-02 23:25:43,292 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/DeepSeek-V3.1/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# Error en el adaptador de OpenAI (DeepSeek-V3.1): Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to DeepSeek-V3.1 for DeepSeek-V3.1 in East US 2 have exceeded the call rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-05-01-preview. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}
# 2025-11-02 23:25:43,293 - root - WARNING - ! Error de parseo (Usuario: 9JL9080GL, LLM: DeepSeek-V3.1, Ctx: False): No se encontró JSON.
# 2025-11-02 23:25:43,349 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/DeepSeek-V3.1/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# Error en el adaptador de OpenAI (DeepSeek-V3.1): Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to DeepSeek-V3.1 for DeepSeek-V3.1 in East US 2 have exceeded the call rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-05-01-preview. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}
# 2025-11-02 23:25:43,350 - root - WARNING - ! Error de parseo (Usuario: CRY0RPU, LLM: DeepSeek-V3.1, Ctx: True): No se encontró JSON.
# 2025-11-02 23:25:43,352 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/DeepSeek-V3.1/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# Error en el adaptador de OpenAI (DeepSeek-V3.1): Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to DeepSeek-V3.1 for DeepSeek-V3.1 in East US 2 have exceeded the call rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-05-01-preview. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}
# 2025-11-02 23:25:43,353 - root - WARNING - ! Error de parseo (Usuario: CRY0RPU, LLM: DeepSeek-V3.1, Ctx: False): No se encontró JSON.
# 2025-11-02 23:25:43,404 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/DeepSeek-V3.1/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# Error en el adaptador de OpenAI (DeepSeek-V3.1): Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to DeepSeek-V3.1 for DeepSeek-V3.1 in East US 2 have exceeded the call rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-05-01-preview. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}
# 2025-11-02 23:25:43,405 - root - WARNING - ! Error de parseo (Usuario: UL98CLGP, LLM: DeepSeek-V3.1, Ctx: False): No se encontró JSON.
# 2025-11-02 23:25:43,452 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/DeepSeek-V3.1/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# Error en el adaptador de OpenAI (DeepSeek-V3.1): Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to DeepSeek-V3.1 for DeepSeek-V3.1 in East US 2 have exceeded the call rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-05-01-preview. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}
# 2025-11-02 23:25:43,454 - root - WARNING - ! Error de parseo (Usuario: YC9RRVYYL, LLM: DeepSeek-V3.1, Ctx: False): No se encontró JSON.
# 2025-11-02 23:25:43,455 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/DeepSeek-V3.1/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# Error en el adaptador de OpenAI (DeepSeek-V3.1): Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to DeepSeek-V3.1 for DeepSeek-V3.1 in East US 2 have exceeded the call rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-05-01-preview. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}
# 2025-11-02 23:25:43,456 - root - WARNING - ! Error de parseo (Usuario: RCV90RLVC, LLM: DeepSeek-V3.1, Ctx: False): No se encontró JSON.
# 2025-11-02 23:25:43,476 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/DeepSeek-V3.1/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# Error en el adaptador de OpenAI (DeepSeek-V3.1): Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to DeepSeek-V3.1 for DeepSeek-V3.1 in East US 2 have exceeded the call rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-05-01-preview. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}
# 2025-11-02 23:25:43,478 - root - WARNING - ! Error de parseo (Usuario: RCV90RLVC, LLM: DeepSeek-V3.1, Ctx: True): No se encontró JSON.
# 2025-11-02 23:25:44,480 - root - INFO -
# --- Ejecutando Lote 3 / 4 (Tamaño: 10) ---
# 2025-11-02 23:25:46,137 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 23:25:47,061 - root - ERROR - ! Error inesperado (Usuario: 999QV8RJU, LLM: Llama-3.3-70B-Instruct, Ctx: True): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=WallBreakers-Miner-Cannon-Bats-Zap-GobGang-MegaKnight
# 2025-11-02 23:25:47,067 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 23:25:48,316 - root - INFO - Éxito: Usuario 2G22QVP89 (LLM: Llama-3.3-70B-Instruct, Ctx: True)
# 2025-11-02 23:25:48,317 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 23:25:48,318 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 23:25:48,319 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 23:25:49,160 - root - INFO - Éxito: Usuario L0092LLGP (LLM: Llama-3.3-70B-Instruct, Ctx: False)
# 2025-11-02 23:25:50,496 - root - ERROR - ! Error inesperado (Usuario: 999QV8RJU, LLM: Llama-3.3-70B-Instruct, Ctx: False): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=WallBreakers-Miner-Cannon-Bats-Barrel-MM-Log
# 2025-11-02 23:25:51,826 - root - ERROR - ! Error inesperado (Usuario: L0092LLGP, LLM: Llama-3.3-70B-Instruct, Ctx: True): 404 Client Error: Not Found for url: https://www.deckshop.pro/check/?deck=MegaKnight-SpearGobs-Bats-Skellies-IceSpirit-Zap-GobGang
# 2025-11-02 23:25:53,353 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 23:25:54,965 - root - INFO - Éxito: Usuario VL0QCY9R8 (LLM: Llama-3.3-70B-Instruct, Ctx: True)
# 2025-11-02 23:25:54,967 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 23:25:58,126 - root - INFO - Éxito: Usuario VL0QCY9R8 (LLM: Llama-3.3-70B-Instruct, Ctx: False)
# 2025-11-02 23:25:58,128 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 23:25:58,128 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 23:25:58,130 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 200 OK"
# 2025-11-02 23:25:59,971 - root - INFO - Éxito: Usuario 2G22QVP89 (LLM: Llama-3.3-70B-Instruct, Ctx: False)
# 2025-11-02 23:26:03,964 - root - INFO - Éxito: Usuario LU2QQJU0Y (LLM: Llama-3.3-70B-Instruct, Ctx: True)
# 2025-11-02 23:26:06,932 - root - INFO - Éxito: Usuario LU2QQJU0Y (LLM: Llama-3.3-70B-Instruct, Ctx: False)
# 2025-11-02 23:26:07,934 - root - INFO -
# --- Ejecutando Lote 4 / 4 (Tamaño: 10) ---
# 2025-11-02 23:26:08,733 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# 2025-11-02 23:26:08,735 - openai._base_client - INFO - Retrying request to /chat/completions in 0.481898 seconds
# 2025-11-02 23:26:08,745 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# 2025-11-02 23:26:08,746 - openai._base_client - INFO - Retrying request to /chat/completions in 0.463147 seconds
# 2025-11-02 23:26:08,752 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# 2025-11-02 23:26:08,755 - openai._base_client - INFO - Retrying request to /chat/completions in 0.482734 seconds
# 2025-11-02 23:26:08,757 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# 2025-11-02 23:26:08,759 - openai._base_client - INFO - Retrying request to /chat/completions in 0.491736 seconds
# 2025-11-02 23:26:08,784 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# 2025-11-02 23:26:08,786 - openai._base_client - INFO - Retrying request to /chat/completions in 0.467681 seconds
# 2025-11-02 23:26:08,787 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# 2025-11-02 23:26:08,788 - openai._base_client - INFO - Retrying request to /chat/completions in 0.389135 seconds
# 2025-11-02 23:26:08,789 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# 2025-11-02 23:26:08,790 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# 2025-11-02 23:26:08,790 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# 2025-11-02 23:26:08,791 - openai._base_client - INFO - Retrying request to /chat/completions in 0.473108 seconds
# 2025-11-02 23:26:08,792 - openai._base_client - INFO - Retrying request to /chat/completions in 0.448947 seconds
# 2025-11-02 23:26:08,793 - openai._base_client - INFO - Retrying request to /chat/completions in 0.476131 seconds
# 2025-11-02 23:26:08,798 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# 2025-11-02 23:26:08,799 - openai._base_client - INFO - Retrying request to /chat/completions in 0.485736 seconds
# 2025-11-02 23:26:09,355 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# 2025-11-02 23:26:09,357 - openai._base_client - INFO - Retrying request to /chat/completions in 0.771670 seconds
# 2025-11-02 23:26:09,359 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# 2025-11-02 23:26:09,360 - openai._base_client - INFO - Retrying request to /chat/completions in 0.755478 seconds
# 2025-11-02 23:26:09,375 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# 2025-11-02 23:26:09,377 - openai._base_client - INFO - Retrying request to /chat/completions in 0.941419 seconds
# 2025-11-02 23:26:09,409 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# 2025-11-02 23:26:09,410 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# 2025-11-02 23:26:09,411 - openai._base_client - INFO - Retrying request to /chat/completions in 0.807304 seconds
# 2025-11-02 23:26:09,412 - openai._base_client - INFO - Retrying request to /chat/completions in 0.917985 seconds
# 2025-11-02 23:26:09,413 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# 2025-11-02 23:26:09,414 - openai._base_client - INFO - Retrying request to /chat/completions in 0.849846 seconds
# 2025-11-02 23:26:09,415 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# 2025-11-02 23:26:09,416 - openai._base_client - INFO - Retrying request to /chat/completions in 0.770748 seconds
# 2025-11-02 23:26:09,428 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# 2025-11-02 23:26:09,429 - openai._base_client - INFO - Retrying request to /chat/completions in 0.782848 seconds
# 2025-11-02 23:26:09,452 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# 2025-11-02 23:26:09,454 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# 2025-11-02 23:26:09,455 - openai._base_client - INFO - Retrying request to /chat/completions in 0.753758 seconds
# 2025-11-02 23:26:09,456 - openai._base_client - INFO - Retrying request to /chat/completions in 0.877852 seconds
# 2025-11-02 23:26:10,283 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# Error en el adaptador de OpenAI (Llama-3.3-70B-Instruct): Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to Llama-3.3-70B-Instruct for Llama-3.3-70B-Instruct in East US 2 have exceeded the call rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-05-01-preview. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}
# 2025-11-02 23:26:10,286 - root - WARNING - ! Error de parseo (Usuario: RCV90RLVC, LLM: Llama-3.3-70B-Instruct, Ctx: False): No se encontró JSON.
# 2025-11-02 23:26:10,287 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# Error en el adaptador de OpenAI (Llama-3.3-70B-Instruct): Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to Llama-3.3-70B-Instruct for Llama-3.3-70B-Instruct in East US 2 have exceeded the call rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-05-01-preview. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}
# 2025-11-02 23:26:10,289 - root - WARNING - ! Error de parseo (Usuario: YC9RRVYYL, LLM: Llama-3.3-70B-Instruct, Ctx: True): No se encontró JSON.
# 2025-11-02 23:26:10,352 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# Error en el adaptador de OpenAI (Llama-3.3-70B-Instruct): Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to Llama-3.3-70B-Instruct for Llama-3.3-70B-Instruct in East US 2 have exceeded the call rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-05-01-preview. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}
# 2025-11-02 23:26:10,354 - root - WARNING - ! Error de parseo (Usuario: CRY0RPU, LLM: Llama-3.3-70B-Instruct, Ctx: True): No se encontró JSON.
# 2025-11-02 23:26:10,363 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# Error en el adaptador de OpenAI (Llama-3.3-70B-Instruct): Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to Llama-3.3-70B-Instruct for Llama-3.3-70B-Instruct in East US 2 have exceeded the call rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-05-01-preview. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}
# 2025-11-02 23:26:10,365 - root - WARNING - ! Error de parseo (Usuario: UL98CLGP, LLM: Llama-3.3-70B-Instruct, Ctx: True): No se encontró JSON.
# 2025-11-02 23:26:10,369 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# Error en el adaptador de OpenAI (Llama-3.3-70B-Instruct): Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to Llama-3.3-70B-Instruct for Llama-3.3-70B-Instruct in East US 2 have exceeded the call rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-05-01-preview. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}
# 2025-11-02 23:26:10,371 - root - WARNING - ! Error de parseo (Usuario: RCV90RLVC, LLM: Llama-3.3-70B-Instruct, Ctx: True): No se encontró JSON.
# 2025-11-02 23:26:10,390 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# Error en el adaptador de OpenAI (Llama-3.3-70B-Instruct): Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to Llama-3.3-70B-Instruct for Llama-3.3-70B-Instruct in East US 2 have exceeded the call rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-05-01-preview. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}
# 2025-11-02 23:26:10,392 - root - WARNING - ! Error de parseo (Usuario: 9JL9080GL, LLM: Llama-3.3-70B-Instruct, Ctx: False): No se encontró JSON.
# 2025-11-02 23:26:10,440 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# Error en el adaptador de OpenAI (Llama-3.3-70B-Instruct): Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to Llama-3.3-70B-Instruct for Llama-3.3-70B-Instruct in East US 2 have exceeded the call rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-05-01-preview. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}
# 2025-11-02 23:26:10,442 - root - WARNING - ! Error de parseo (Usuario: UL98CLGP, LLM: Llama-3.3-70B-Instruct, Ctx: False): No se encontró JSON.
# 2025-11-02 23:26:10,470 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# Error en el adaptador de OpenAI (Llama-3.3-70B-Instruct): Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to Llama-3.3-70B-Instruct for Llama-3.3-70B-Instruct in East US 2 have exceeded the call rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-05-01-preview. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}
# 2025-11-02 23:26:10,471 - root - WARNING - ! Error de parseo (Usuario: CRY0RPU, LLM: Llama-3.3-70B-Instruct, Ctx: False): No se encontró JSON.
# 2025-11-02 23:26:10,475 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# Error en el adaptador de OpenAI (Llama-3.3-70B-Instruct): Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to Llama-3.3-70B-Instruct for Llama-3.3-70B-Instruct in East US 2 have exceeded the call rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-05-01-preview. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}
# 2025-11-02 23:26:10,476 - root - WARNING - ! Error de parseo (Usuario: YC9RRVYYL, LLM: Llama-3.3-70B-Instruct, Ctx: False): No se encontró JSON.
# 2025-11-02 23:26:10,485 - httpx - INFO - HTTP Request: POST https://victo-mhcmsfx4-eastus2.cognitiveservices.azure.com/openai/deployments/Llama-3.3-70B-Instruct/chat/completions?api-version=2024-05-01-preview "HTTP/1.1 429 Too Many Requests"
# Error en el adaptador de OpenAI (Llama-3.3-70B-Instruct): Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to Llama-3.3-70B-Instruct for Llama-3.3-70B-Instruct in East US 2 have exceeded the call rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-05-01-preview. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}
# 2025-11-02 23:26:10,486 - root - WARNING - ! Error de parseo (Usuario: 9JL9080GL, LLM: Llama-3.3-70B-Instruct, Ctx: True): No se encontró JSON.
# 2025-11-02 23:26:11,489 - root - INFO -
# --- Procesamiento de lotes completado. ---
# 2025-11-02 23:26:11,490 - root - INFO - Resultados válidos (parseados y guardados): 17 de 40
# 2025-11-02 23:26:11,520 - root - INFO - Ejecución finalizada.
# 2025-11-02 23:26:11,521 - root - INFO - Resultados válidos guardados en: 'results/valid_results_20251102_232520.jsonl'
# 2025-11-02 23:26:11,521 - root - INFO - Resultados crudos guardados en: 'results/raw_results_20251102_232520.jsonl'

# %%
df = pd.read_json(output_filename, orient="records", lines=True)

# %%
df['correct_selection_count'] = df.apply(
    lambda row: sum(1 for item in row['deleted'] if item in row['seleccion']),
    axis=1
)
df.head()
# Out:
#                                           seleccion    user_id  \
# 0  [Goblin Barrel, The Log, Inferno Tower, Minions]  2G22QVP89
# 1           [Tornado, Ice Golem, Skeletons, Cannon]  LU2QQJU0Y
# 2         [Poison, Skeletons, The Log, Goblin Gang]  999QV8RJU
# 3      [Miner, Poison, Inferno Dragon, Goblin Gang]  VL0QCY9R8
# 4                 [Miner, Poison, Goblin Gang, Zap]  L0092LLGP
#
#                                           deleted  \
# 0  [Royal Recruits, Goblin Cage, Zappies, Arrows]
# 1  [Musketeer, Minions, Mega Knight, Firecracker]
# 2        [The Log, Goblin Gang, Zap, Mega Knight]
# 3       [Zap, Mega Knight, Bandit, Spear Goblins]
# 4     [Bandit, Skeleton Barrel, Zap, Firecracker]
#
#                                             original            llm  \
# 0  [Electro Spirit, Flying Machine, Golden Knight...  DeepSeek-V3.1
# 1  [Electro Wizard, Hog Rider, Executioner, The Log]  DeepSeek-V3.1
# 2               [Wall Breakers, Miner, Cannon, Bats]  DeepSeek-V3.1
# 3    [Firecracker, Bats, Skeletons, Skeleton Barrel]  DeepSeek-V3.1
# 4      [Mega Knight, Spear Goblins, Bats, Skeletons]  DeepSeek-V3.1
#
#    with_context                               original_deck_rating  \
# 0         False  {'Attack': 3, 'Defense': 5, 'Synergy': 1, 'Ver...
# 1         False  {'Attack': 4, 'Defense': 5, 'Synergy': 4, 'Ver...
# 2         False  {'Attack': 4, 'Defense': 5, 'Synergy': 5, 'Ver...
# 3          True  {'Attack': 3, 'Defense': 5, 'Synergy': 4, 'Ver...
# 4          True  {'Attack': 3, 'Defense': 5, 'Synergy': 4, 'Ver...
#
#                                 selected_deck_rating  \
# 0  {'Attack': 4, 'Defense': 5, 'Synergy': 2, 'Ver...
# 1  {'Attack': 2, 'Defense': 5, 'Synergy': 2, 'Ver...
# 2  {'Attack': 3, 'Defense': 5, 'Synergy': 4, 'Ver...
# 3  {'Attack': 4, 'Defense': 5, 'Synergy': 5, 'Ver...
# 4  {'Attack': 3, 'Defense': 5, 'Synergy': 5, 'Ver...
#
#    total_original_deck_rating  total_selected_deck_rating  was_improved  \
# 0                          15                          18          True
# 1                          20                          14         False
# 2                          20                          17         False
# 3                          20                          22          True
# 4                          20                          19         False
#
#    correct_selection_count
# 0                        0
# 1                        0
# 2                        2
# 3                        0
# 4                        1

# %%
df['correct_selection_count'].groupby(df['llm']).value_counts()
# Out:
# llm                     correct_selection_count
# DeepSeek-V3.1           0                          7
#                         1                          1
#                         2                          1
#                         3                          1
# Llama-3.3-70B-Instruct  0                          6
#                         1                          1
# Name: count, dtype: int64

# %%
res = (
    df.assign(wi=lambda d: d["was_improved"].astype(bool))
      .groupby("llm", as_index=False)
      .agg(total_mazos=("llm", "size"),
           mazos_mejorados=("wi", "sum"))
)
# Agregamos porcentaje de mazos mejorados
res['porcentaje_mejorados'] = (res['mazos_mejorados'] / res['total_mazos']) * 100
print(res)
# Out:
#                       llm  total_mazos  mazos_mejorados  porcentaje_mejorados
# 0           DeepSeek-V3.1           10                5             50.000000
# 1  Llama-3.3-70B-Instruct            7                2             28.571429

# %%
df_raw = pd.read_json(raw_filename, orient="records", lines=True)

# %%
# contamos cuantos validos e invalidos hay en raw_data para cada llm
df_raw['is_valid'] = df_raw['parsed_successfully'].astype(bool)
df_raw['llm'] = df_raw['llm'].astype('category')
df_raw['llm'].cat.categories
df_raw['is_valid'].groupby(df_raw['llm']).value_counts()
# Ponemos el porcentaje de validos por llm
df_raw.groupby('llm')['is_valid'].value_counts(normalize=True).mul(100)
# Out:
# /var/folders/jv/rmw91d8n0g15ldpn_dkk73rh0000gn/T/ipykernel_96029/17924982.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_raw['is_valid'].groupby(df_raw['llm']).value_counts()
# /var/folders/jv/rmw91d8n0g15ldpn_dkk73rh0000gn/T/ipykernel_96029/17924982.py:7: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_raw.groupby('llm')['is_valid'].value_counts(normalize=True).mul(100)
# llm                     is_valid
# DeepSeek-V3.1           False       50.0
#                         True        50.0
# Llama-3.3-70B-Instruct  False       65.0
#                         True        35.0
# Name: proportion, dtype: float64

# %%
hola_serie = df_raw['raw_response'][(df_raw['user_id'] == '999QV8RJU') & (df_raw['llm'] == 'Llama-3.3-70B-Instruct')]

if not hola_serie.empty:
    texto_completo = hola_serie.iloc[0]
    
    print(texto_completo)
else:
    print("No se encontró esa fila.")
# Out:
# ```json
# {
#   "seleccion": [
#     "Zap",
#     "Goblin Gang",
#     "Mega Knight"
#   ]
# }
# ```
