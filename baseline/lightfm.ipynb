# %% [markdown]
# # LightFM

# %% [markdown]
# [making.lyst.com/lightfm](https://making.lyst.com/lightfm/docs/lightfm.html#lightfm)

# %% [markdown]
# ## Constantes

# %%
K = 4
TEST_PERCENTAGE = 0.25
LEARNING_RATE = 0.25
LOSS_FUNCTION = 'warp'
NO_COMPONENTS = 20
NO_EPOCHS = 20
NO_THREADS = 32
ITEM_ALPHA = 1e-6
USER_ALPHA = 1e-6

SEED = 42

# %% [markdown]
# ## Importaciones

# %%
import pandas as pd

# %%
# !python -m pip install git+https://github.com/daviddavo/lightfm
# Out:
# Collecting git+https://github.com/daviddavo/lightfm
#   Cloning https://github.com/daviddavo/lightfm to /tmp/pip-req-build-4grfxrvl
#   Running command git clone --filter=blob:none --quiet https://github.com/daviddavo/lightfm /tmp/pip-req-build-4grfxrvl
#   Resolved https://github.com/daviddavo/lightfm to commit f0eb500ead54ab65eb8e1b3890337a7223a35114
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from lightfm==1.17) (2.2.6)
# Requirement already satisfied: scipy>=0.17.0 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from lightfm==1.17) (1.15.3)
# Requirement already satisfied: requests in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from lightfm==1.17) (2.32.5)
# Requirement already satisfied: scikit-learn in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from lightfm==1.17) (1.7.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from requests->lightfm==1.17) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from requests->lightfm==1.17) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from requests->lightfm==1.17) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from requests->lightfm==1.17) (2025.8.3)
# Requirement already satisfied: joblib>=1.2.0 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from scikit-learn->lightfm==1.17) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from scikit-learn->lightfm==1.17) (3.6.0)

# %%
# !python -m pip install recommenders
# Out:
# Requirement already satisfied: recommenders in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (1.2.1)
# Requirement already satisfied: category-encoders<3,>=2.6.0 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from recommenders) (2.8.1)
# Requirement already satisfied: cornac<3,>=1.15.2 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from recommenders) (2.3.3)
# Requirement already satisfied: hyperopt<1,>=0.2.7 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from recommenders) (0.2.7)
# Requirement already satisfied: lightgbm<5,>=4.0.0 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from recommenders) (4.6.0)
# Requirement already satisfied: locust<3,>=2.12.2 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from recommenders) (2.40.2)
# Requirement already satisfied: memory-profiler<1,>=0.61.0 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from recommenders) (0.61.0)
# Requirement already satisfied: nltk<4,>=3.8.1 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from recommenders) (3.9.1)
# Requirement already satisfied: notebook<8,>=6.5.5 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from recommenders) (7.4.5)
# Requirement already satisfied: numba<1,>=0.57.0 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from recommenders) (0.61.2)
# Requirement already satisfied: pandas<3.0.0,>2.0.0 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from recommenders) (2.3.2)
# Requirement already satisfied: retrying<2,>=1.3.4 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from recommenders) (1.4.2)
# Requirement already satisfied: scikit-learn<2,>=1.2.0 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from recommenders) (1.7.1)
# Requirement already satisfied: scikit-surprise>=1.1.3 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from recommenders) (1.1.4)
# Requirement already satisfied: seaborn<1,>=0.13.0 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from recommenders) (0.13.2)
# Requirement already satisfied: transformers<5,>=4.27.0 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from recommenders) (4.56.1)
# Requirement already satisfied: pandera>=0.15.0 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from pandera[strategies]>=0.15.0; python_version >= "3.9"->recommenders) (0.26.1)
# Requirement already satisfied: statsmodels>=0.14.4 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from recommenders) (0.14.5)
# Requirement already satisfied: numpy>=1.14.0 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from category-encoders<3,>=2.6.0->recommenders) (2.2.6)
# Requirement already satisfied: patsy>=0.5.1 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from category-encoders<3,>=2.6.0->recommenders) (1.0.1)
# Requirement already satisfied: scipy>=1.0.0 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from category-encoders<3,>=2.6.0->recommenders) (1.15.3)
# Requirement already satisfied: tqdm in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from cornac<3,>=1.15.2->recommenders) (4.67.1)
# Requirement already satisfied: powerlaw in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from cornac<3,>=1.15.2->recommenders) (1.5)
# Requirement already satisfied: six in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from hyperopt<1,>=0.2.7->recommenders) (1.17.0)
# Requirement already satisfied: networkx>=2.2 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from hyperopt<1,>=0.2.7->recommenders) (3.4.2)
# Requirement already satisfied: future in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from hyperopt<1,>=0.2.7->recommenders) (1.0.0)
# Requirement already satisfied: cloudpickle in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from hyperopt<1,>=0.2.7->recommenders) (3.1.1)
# Requirement already satisfied: py4j in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from hyperopt<1,>=0.2.7->recommenders) (0.10.9.9)
# Requirement already satisfied: configargparse>=1.7.1 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from locust<3,>=2.12.2->recommenders) (1.7.1)
# Requirement already satisfied: flask-cors>=3.0.10 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from locust<3,>=2.12.2->recommenders) (6.0.1)
# Requirement already satisfied: flask-login>=0.6.3 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from locust<3,>=2.12.2->recommenders) (0.6.3)
# Requirement already satisfied: flask>=2.0.0 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from locust<3,>=2.12.2->recommenders) (3.1.2)
# Requirement already satisfied: gevent<25.8.1,>=24.10.1 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from locust<3,>=2.12.2->recommenders) (25.5.1)
# Requirement already satisfied: geventhttpclient>=2.3.1 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from locust<3,>=2.12.2->recommenders) (2.3.4)
# Requirement already satisfied: locust-cloud>=1.26.3 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from locust<3,>=2.12.2->recommenders) (1.26.3)
# Requirement already satisfied: msgpack>=1.0.0 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from locust<3,>=2.12.2->recommenders) (1.1.1)
# Requirement already satisfied: psutil>=5.9.1 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from locust<3,>=2.12.2->recommenders) (7.0.0)
# Requirement already satisfied: pytest<9.0.0,>=8.3.3 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from locust<3,>=2.12.2->recommenders) (8.4.2)
# Requirement already satisfied: python-engineio>=4.12.2 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from locust<3,>=2.12.2->recommenders) (4.12.2)
# Requirement already satisfied: python-socketio>=5.13.0 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from python-socketio[client]>=5.13.0->locust<3,>=2.12.2->recommenders) (5.13.0)
# Requirement already satisfied: pyzmq>=25.0.0 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from locust<3,>=2.12.2->recommenders) (27.0.2)
# Requirement already satisfied: requests>=2.26.0 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from locust<3,>=2.12.2->recommenders) (2.32.5)
# Requirement already satisfied: setuptools>=70.0.0 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from locust<3,>=2.12.2->recommenders) (78.1.1)
# Requirement already satisfied: tomli>=1.1.0 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from locust<3,>=2.12.2->recommenders) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from locust<3,>=2.12.2->recommenders) (4.15.0)
# Requirement already satisfied: werkzeug>=2.0.0 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from locust<3,>=2.12.2->recommenders) (3.1.3)
# Requirement already satisfied: greenlet>=3.2.2 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from gevent<25.8.1,>=24.10.1->locust<3,>=2.12.2->recommenders) (3.2.4)
# Requirement already satisfied: zope.event in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from gevent<25.8.1,>=24.10.1->locust<3,>=2.12.2->recommenders) (5.1.1)
# Requirement already satisfied: zope.interface in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from gevent<25.8.1,>=24.10.1->locust<3,>=2.12.2->recommenders) (7.2)
# Requirement already satisfied: click in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from nltk<4,>=3.8.1->recommenders) (8.2.1)
# Requirement already satisfied: joblib in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from nltk<4,>=3.8.1->recommenders) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from nltk<4,>=3.8.1->recommenders) (2025.9.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from notebook<8,>=6.5.5->recommenders) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from notebook<8,>=6.5.5->recommenders) (2.27.3)
# Requirement already satisfied: jupyterlab<4.5,>=4.4.5 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from notebook<8,>=6.5.5->recommenders) (4.4.7)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from notebook<8,>=6.5.5->recommenders) (0.2.4)
# Requirement already satisfied: tornado>=6.2.0 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from notebook<8,>=6.5.5->recommenders) (6.5.2)
# Requirement already satisfied: anyio>=3.1.0 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (4.10.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (25.1.0)
# Requirement already satisfied: jinja2>=3.0.3 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (3.1.6)
# Requirement already satisfied: jupyter-client>=7.4.4 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (5.8.1)
# Requirement already satisfied: jupyter-events>=0.11.0 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (7.16.6)
# Requirement already satisfied: nbformat>=5.3.0 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (7.7.0)
# Requirement already satisfied: packaging>=22.0 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (25.0)
# Requirement already satisfied: prometheus-client>=0.9 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (0.22.1)
# Requirement already satisfied: send2trash>=1.8.2 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (0.18.1)
# Requirement already satisfied: traitlets>=5.6.0 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (5.14.3)
# Requirement already satisfied: websocket-client>=1.7 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from jupyterlab<4.5,>=4.4.5->notebook<8,>=6.5.5->recommenders) (2.0.5)
# Requirement already satisfied: httpx<1,>=0.25.0 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from jupyterlab<4.5,>=4.4.5->notebook<8,>=6.5.5->recommenders) (0.28.1)
# Requirement already satisfied: ipykernel!=6.30.0,>=6.5.0 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from jupyterlab<4.5,>=4.4.5->notebook<8,>=6.5.5->recommenders) (6.30.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from jupyterlab<4.5,>=4.4.5->notebook<8,>=6.5.5->recommenders) (2.3.0)
# Requirement already satisfied: certifi in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from httpx<1,>=0.25.0->jupyterlab<4.5,>=4.4.5->notebook<8,>=6.5.5->recommenders) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from httpx<1,>=0.25.0->jupyterlab<4.5,>=4.4.5->notebook<8,>=6.5.5->recommenders) (1.0.9)
# Requirement already satisfied: idna in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from httpx<1,>=0.25.0->jupyterlab<4.5,>=4.4.5->notebook<8,>=6.5.5->recommenders) (3.10)
# Requirement already satisfied: h11>=0.16 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab<4.5,>=4.4.5->notebook<8,>=6.5.5->recommenders) (0.16.0)
# Requirement already satisfied: babel>=2.10 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->notebook<8,>=6.5.5->recommenders) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->notebook<8,>=6.5.5->recommenders) (0.12.1)
# Requirement already satisfied: jsonschema>=4.18.0 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->notebook<8,>=6.5.5->recommenders) (4.25.1)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from numba<1,>=0.57.0->recommenders) (0.44.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from pandas<3.0.0,>2.0.0->recommenders) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from pandas<3.0.0,>2.0.0->recommenders) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from pandas<3.0.0,>2.0.0->recommenders) (2025.2)
# Requirement already satisfied: exceptiongroup>=1 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from pytest<9.0.0,>=8.3.3->locust<3,>=2.12.2->recommenders) (1.3.0)
# Requirement already satisfied: iniconfig>=1 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from pytest<9.0.0,>=8.3.3->locust<3,>=2.12.2->recommenders) (2.1.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from pytest<9.0.0,>=8.3.3->locust<3,>=2.12.2->recommenders) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from pytest<9.0.0,>=8.3.3->locust<3,>=2.12.2->recommenders) (2.19.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from scikit-learn<2,>=1.2.0->recommenders) (3.6.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from seaborn<1,>=0.13.0->recommenders) (3.10.6)
# Requirement already satisfied: filelock in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from transformers<5,>=4.27.0->recommenders) (3.19.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from transformers<5,>=4.27.0->recommenders) (0.34.4)
# Requirement already satisfied: pyyaml>=5.1 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from transformers<5,>=4.27.0->recommenders) (6.0.2)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from transformers<5,>=4.27.0->recommenders) (0.22.0)
# Requirement already satisfied: safetensors>=0.4.3 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from transformers<5,>=4.27.0->recommenders) (0.6.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers<5,>=4.27.0->recommenders) (2025.9.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers<5,>=4.27.0->recommenders) (1.1.9)
# Requirement already satisfied: sniffio>=1.1 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (25.1.0)
# Requirement already satisfied: blinker>=1.9.0 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from flask>=2.0.0->locust<3,>=2.12.2->recommenders) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from flask>=2.0.0->locust<3,>=2.12.2->recommenders) (2.2.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from flask>=2.0.0->locust<3,>=2.12.2->recommenders) (3.0.2)
# Requirement already satisfied: brotli in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from geventhttpclient>=2.3.1->locust<3,>=2.12.2->recommenders) (1.1.0)
# Requirement already satisfied: urllib3 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from geventhttpclient>=2.3.1->locust<3,>=2.12.2->recommenders) (2.5.0)
# Requirement already satisfied: comm>=0.1.1 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook<8,>=6.5.5->recommenders) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook<8,>=6.5.5->recommenders) (1.8.16)
# Requirement already satisfied: ipython>=7.23.1 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook<8,>=6.5.5->recommenders) (8.37.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook<8,>=6.5.5->recommenders) (0.1.7)
# Requirement already satisfied: nest-asyncio>=1.4 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook<8,>=6.5.5->recommenders) (1.6.0)
# Requirement already satisfied: decorator in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook<8,>=6.5.5->recommenders) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook<8,>=6.5.5->recommenders) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook<8,>=6.5.5->recommenders) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook<8,>=6.5.5->recommenders) (3.0.52)
# Requirement already satisfied: stack_data in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook<8,>=6.5.5->recommenders) (0.6.3)
# Requirement already satisfied: wcwidth in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook<8,>=6.5.5->recommenders) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook<8,>=6.5.5->recommenders) (0.8.5)
# Requirement already satisfied: attrs>=22.2.0 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook<8,>=6.5.5->recommenders) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook<8,>=6.5.5->recommenders) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook<8,>=6.5.5->recommenders) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook<8,>=6.5.5->recommenders) (0.27.1)
# Requirement already satisfied: platformdirs>=2.5 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (4.4.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (3.3.0)
# Requirement already satisfied: rfc3339-validator in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (0.1.1)
# Requirement already satisfied: fqdn in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (1.5.1)
# Requirement already satisfied: isoduration in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (1.1.0)
# Requirement already satisfied: uri-template in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (24.11.1)
# Requirement already satisfied: bidict>=0.21.0 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from python-socketio>=5.13.0->python-socketio[client]>=5.13.0->locust<3,>=2.12.2->recommenders) (0.23.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn<1,>=0.13.0->recommenders) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn<1,>=0.13.0->recommenders) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn<1,>=0.13.0->recommenders) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn<1,>=0.13.0->recommenders) (1.4.9)
# Requirement already satisfied: pillow>=8 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn<1,>=0.13.0->recommenders) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn<1,>=0.13.0->recommenders) (3.2.3)
# Requirement already satisfied: beautifulsoup4 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (6.2.0)
# Requirement already satisfied: defusedxml in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (3.1.4)
# Requirement already satisfied: nbclient>=0.5.0 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (1.5.1)
# Requirement already satisfied: webencodings in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (2.21.2)
# Requirement already satisfied: pydantic in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from pandera>=0.15.0->pandera[strategies]>=0.15.0; python_version >= "3.9"->recommenders) (2.11.7)
# Requirement already satisfied: typeguard in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from pandera>=0.15.0->pandera[strategies]>=0.15.0; python_version >= "3.9"->recommenders) (4.4.4)
# Requirement already satisfied: typing_inspect>=0.6.0 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from pandera>=0.15.0->pandera[strategies]>=0.15.0; python_version >= "3.9"->recommenders) (0.9.0)
# Requirement already satisfied: hypothesis>=6.92.7 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from pandera[strategies]>=0.15.0; python_version >= "3.9"->recommenders) (6.138.15)
# Requirement already satisfied: sortedcontainers<3.0.0,>=2.1.0 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from hypothesis>=6.92.7->pandera[strategies]>=0.15.0; python_version >= "3.9"->recommenders) (2.4.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook<8,>=6.5.5->recommenders) (0.7.0)
# Requirement already satisfied: simple-websocket>=0.10.0 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from python-engineio>=4.12.2->locust<3,>=2.12.2->recommenders) (1.1.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from requests>=2.26.0->locust<3,>=2.12.2->recommenders) (3.4.3)
# Requirement already satisfied: lark>=1.2.2 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (1.2.2)
# Requirement already satisfied: wsproto in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from simple-websocket>=0.10.0->python-engineio>=4.12.2->locust<3,>=2.12.2->recommenders) (1.2.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from typing_inspect>=0.6.0->pandera>=0.15.0->pandera[strategies]>=0.15.0; python_version >= "3.9"->recommenders) (1.1.0)
# Requirement already satisfied: cffi>=1.0.1 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (1.17.1)
# Requirement already satisfied: pycparser in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (2.22)
# Requirement already satisfied: soupsieve>1.2 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (2.8)
# Requirement already satisfied: arrow>=0.15.0 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (2.9.0.20250822)
# Requirement already satisfied: mpmath in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from powerlaw->cornac<3,>=1.15.2->recommenders) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from pydantic->pandera>=0.15.0->pandera[strategies]>=0.15.0; python_version >= "3.9"->recommenders) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from pydantic->pandera>=0.15.0->pandera[strategies]>=0.15.0; python_version >= "3.9"->recommenders) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from pydantic->pandera>=0.15.0->pandera[strategies]>=0.15.0; python_version >= "3.9"->recommenders) (0.4.1)
# Requirement already satisfied: executing>=1.2.0 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from stack_data->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook<8,>=6.5.5->recommenders) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from stack_data->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook<8,>=6.5.5->recommenders) (3.0.0)
# Requirement already satisfied: pure-eval in /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages (from stack_data->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook<8,>=6.5.5->recommenders) (0.2.3)

# %%
import os
import sys
import itertools
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import lightfm
from lightfm import LightFM
from lightfm.data import Dataset
from lightfm import cross_validation
from lightfm.evaluation import precision_at_k as lightfm_prec_at_k
from lightfm.evaluation import recall_at_k as lightfm_recall_at_k

from recommenders.evaluation.python_evaluation import precision_at_k, recall_at_k
from recommenders.utils.timer import Timer
from recommenders.datasets import movielens
from recommenders.models.lightfm.lightfm_utils import (
    track_model_metrics,
    prepare_test_df,
    prepare_all_predictions,
    compare_metric,
    similar_users,
    similar_items,
)
from recommenders.utils.notebook_utils import store_metadata

print("System version: {}".format(sys.version))
print("LightFM version: {}".format(lightfm.__version__))
# Out:
# System version: 3.10.18 (main, Jun  5 2025, 13:14:17) [GCC 11.2.0]
# LightFM version: 1.17
# /home/victo/miniconda3/envs/recsys/lib/python3.10/site-packages/pandera/_pandas_deprecated.py:160: FutureWarning: Importing pandas-specific classes and functions from the
# top-level pandera module will be **removed in a future version of pandera**.
# If you're using pandera to validate pandas objects, we highly recommend updating
# your import:
#
# ```
# # old import
# import pandera as pa
#
# # new import
# import pandera.pandas as pa
# ```
#
# If you're using pandera to validate objects from other compatible libraries
# like pyspark or polars, see the supported libraries section of the documentation
# for more information on how to import pandera:
#
# https://pandera.readthedocs.io/en/stable/supported_libraries.html
#
# To disable this warning, set the environment variable:
#
# ```
# export DISABLE_PANDERA_IMPORT_WARNING=True
# ```
#
#   warnings.warn(_future_warning, FutureWarning)

# %% [markdown]
# ### Dataframe

# %%
n_users = int(11000/8)
random_state = SEED
ratings = pd.read_csv("../data/player_cards.csv")
sampled_users = ratings["tag"].drop_duplicates().sample(n=n_users, random_state=random_state)
ratings = ratings[ratings["tag"].isin(sampled_users)]
card_cols = [col for col in ratings.columns if col != "tag"]
ratings = pd.melt(ratings, id_vars="tag", value_vars=card_cols, var_name="card", value_name="rating")
ratings.rename(columns={"tag": "player"}, inplace=True)
df = ratings[ratings["rating"] == 2]

# %%
df
# Out:
#              player      card  rating
# 0        #VY08Q8V89  26000000       2
# 6        #G2ULJQVVC  26000000       2
# 13        #PQCGQ2QR  26000000       2
# 14       #9PQ00CRRJ  26000000       2
# 16       #VLQ82UQCJ  26000000       2
# ...             ...       ...     ...
# 166277   #JYYU2P9RC  28000026       2
# 166289  #200JPP8YC2  28000026       2
# 166305   #PVP99UQUV  28000026       2
# 166325   #VGG0U8QU0  28000026       2
# 166350      #U00YUY  28000026       2
#
# [10970 rows x 3 columns]

# %% [markdown]
# ### Preparación datos

# %%
data = df.rename(columns={"player": "userID", "card": "itemID"})
data
# Out:
#              userID    itemID  rating
# 0        #VY08Q8V89  26000000       2
# 6        #G2ULJQVVC  26000000       2
# 13        #PQCGQ2QR  26000000       2
# 14       #9PQ00CRRJ  26000000       2
# 16       #VLQ82UQCJ  26000000       2
# ...             ...       ...     ...
# 166277   #JYYU2P9RC  28000026       2
# 166289  #200JPP8YC2  28000026       2
# 166305   #PVP99UQUV  28000026       2
# 166325   #VGG0U8QU0  28000026       2
# 166350      #U00YUY  28000026       2
#
# [10970 rows x 3 columns]

# %% [markdown]
# Se esconden 4 cartas para test, para simular el proceso de darle 4 cartas al LLM y que complete el resto del mazo (de 8 cartas).

# %%
np.random.seed(42)

grouped = data.groupby("userID")

train_rows = []
test_rows = []

for user, group in grouped:
    if len(group) < 8:
        continue

    shuffled = group.sample(frac=1)

    train = shuffled.iloc[:4]
    test = shuffled.iloc[4:]

    train_rows.append(train)
    test_rows.append(test)

df_train = pd.concat(train_rows)
df_test = pd.concat(test_rows)

print(df_train.shape, df_test.shape)
# Out:
# (5468, 3) (5468, 3)

# %%
dataset = Dataset()

dataset.fit(users=data["userID"], items=data["itemID"])

num_players, num_cards = dataset.interactions_shape()
print(f'Num players: {num_players}, num cards: {num_cards}.')
# Out:
# Num players: 1375, num cards: 121.

# %%
(interactions, weights) = dataset.build_interactions(data.iloc[:, 0:3].values)
(train_interactions, _) = dataset.build_interactions(df_train.iloc[:, 0:3].values)
(test_interactions, _) = dataset.build_interactions(df_test.iloc[:, 0:3].values)

# %%
print(f"Shape of train interactions: {train_interactions.shape}")
print(f"Shape of test interactions: {test_interactions.shape}")
# Out:
# Shape of train interactions: (1375, 121)
# Shape of test interactions: (1375, 121)

# %% [markdown]
# ### Entrenamiento modelo

# %%
model = LightFM(loss=LOSS_FUNCTION, no_components=NO_COMPONENTS,
    learning_rate=LEARNING_RATE,
    random_state=np.random.RandomState(SEED))

# %%
model.fit(interactions=train_interactions,
    epochs=NO_EPOCHS);

# %% [markdown]
# ### Preparación de datos para evaluación

# %%
uids, iids, interaction_data = cross_validation._shuffle(
    interactions.row, interactions.col, interactions.data,
    random_state=np.random.RandomState(SEED))

cutoff = int((1.0 - TEST_PERCENTAGE) * len(uids))
test_idx = slice(cutoff, None)

# %%
uid_map, ufeature_map, iid_map, ifeature_map = dataset.mapping()

# %%
with Timer() as test_time:
    test_df = prepare_test_df(test_idx, uids, iids, uid_map, iid_map, weights)
print(f"Took {test_time.interval:.1f} seconds for prepare and predict test data.")
time_reco1 = test_time.interval
# Out:
# Took 0.1 seconds for prepare and predict test data.

# %%
test_df.sample(5, random_state=SEED)
# Out:
#           userID    itemID  rating
# 859    #LYCPJGCY  27000006     2.0
# 1521  #JRVVYRYQ0  26000055     2.0
# 1322  #2Q009QRQU  26000077     2.0
# 1352  #V8PVRJCGJ  26000005     2.0
# 2031  #JJRV0QYUL  26000072     2.0

# %%
with Timer() as test_time:
    all_predictions = prepare_all_predictions(data, uid_map, iid_map,
        interactions=train_interactions,
        model=model,
        num_threads=NO_THREADS)
print(f"Took {test_time.interval:.1f} seconds for prepare and predict all data.")
time_reco2 = test_time.interval
# Out:
# Took 216.3 seconds for prepare and predict all data.

# %%
all_predictions.sample(5, random_state=SEED)
# Out:
#             userID    itemID  prediction
# 34756   #YLLCCJ8CU  28000018   -2.798141
# 50562     #2PPC02V  26000007   -4.536026
# 116454  #C9YU2VYUV  26000024   -2.129728
# 66073   #UVC8JQYRR  26000080   -8.862637
# 46885   #QVV82LLV2  26000093  -13.315029

# %% [markdown]
# ### Evaluación

# %%
with Timer() as test_time:
    eval_precision = precision_at_k(rating_true=test_df,
        rating_pred=all_predictions, k=K)
    eval_recall = recall_at_k(test_df, all_predictions, k=K)
time_reco3 = test_time.interval

with Timer() as test_time:
    eval_precision_lfm = lightfm_prec_at_k(model, test_interactions,
        train_interactions, k=K).mean()
    eval_recall_lfm = lightfm_recall_at_k(model, test_interactions,
        train_interactions, k=K).mean()
time_lfm = test_time.interval

print(
    "------ Using Repo's evaluation methods ------",
    f"Precision@{K}:\t{eval_precision:.6f}",
    f"Recall@{K}:\t{eval_recall:.6f}",
    "\n------ Using LightFM evaluation methods ------",
    f"Precision@{K}:\t{eval_precision_lfm:.6f}",
    f"Recall@{K}:\t{eval_recall_lfm:.6f}",
    sep='\n')
# Out:
# ------ Using Repo's evaluation methods ------
# Precision@4:	0.039495
# Recall@4:	0.073439
#
# ------ Using LightFM evaluation methods ------
# Precision@4:	0.128749
# Recall@4:	0.128749
